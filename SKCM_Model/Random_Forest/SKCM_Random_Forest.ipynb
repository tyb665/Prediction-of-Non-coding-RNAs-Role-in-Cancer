# %% [markdown]
# # PRAD 中 MIR100HG 表达状态预测 - 随机森林建模流程
#
# ## 1. 数据信息
#
# | 数据类型       | 文件名                                       | 样本数 | 特征数 |
# |----------------|----------------------------------------------|--------|--------|
# | 表达标签数据   | PRAD_Model_MIR100HG_Expression_Levels.csv    | 495    | 4      |
# | 基因表达数据   | PRAD_Model_Gene_Expression_Features.csv      | 3737   | 496    |
# | 甲基化数据     | PRAD_Model_Methylation_Features.csv          | 233    | 500    |
#
# ---
#
# ## 2. 数据预处理
#
# | 步骤                | 操作内容                                                         |
# |---------------------|------------------------------------------------------------------|
# | MIR100HG处理        | 检测并剔除目标基因 `MIR100HG` 特征                              |
# | 样本转置            | 基因表达、甲基化数据按样本维度转置                              |
# | 特征前缀添加        | 表达特征加前缀 `Gene_`，甲基化特征加前缀 `Methylation_`        |
# | 特征合并后形状      | 495 个样本 × 3970 个特征（Gene: 3737 + Methylation: 233）       |
#
# ---
#
# ## 3. 数据集划分
#
# | 数据集     | 样本数 |
# |------------|--------|
# | 训练集     | 396    |
# | 测试集     | 99     |
#
# ---
#
# ## 4. 特征选择（仅在训练集）
#
# | 操作阶段         | 基因表达 | 甲基化 | 合计 |
# |------------------|----------|--------|------|
# | 方差过滤后特征数 | 3740     | 233    | 3973 |
# | ANOVA筛选后特征  | 200      | 100    | 300  |
#
# ---
#
# ## 5. 模型训练：随机森林
#
# ---
#
# ## 6. 特征重要性分析
#
# ### 特征来源比例
#
# | 特征来源     | 占比    |
# |--------------|---------|
# | 基因表达     | 93.25%  |
# | 甲基化       | 6.75%   |
#
# ### Top 20 基因表达特征
#
# | 排名 | 特征名         | 权重     | 占比 (%)  |
# |------|----------------|----------|-----------|
# | 1    | Gene_SLC16A4   | 0.039162 | 3.9162    |
# | 2    | Gene_SMIM10    | 0.033887 | 3.3887    |
# | 3    | Gene_CNRIP1    | 0.033362 | 3.3362    |
# | 4    | Gene_MEIS1     | 0.028038 | 2.8038    |
# | 5    | Gene_KCNJ8     | 0.026697 | 2.6697    |
# | 6    | Gene_PMP22     | 0.024751 | 2.4751    |
# | 7    | Gene_EDNRA     | 0.022453 | 2.2453    |
# | 8    | Gene_SPARCL1   | 0.020670 | 2.0670    |
# | 9    | Gene_KANK2     | 0.018961 | 1.8961    |
# | 10   | Gene_TMEM200B  | 0.017943 | 1.7943    |
# | 11   | Gene_GFPT2     | 0.017888 | 1.7888    |
# | 12   | Gene_MRGPRF    | 0.017470 | 1.7470    |
# | 13   | Gene_RBMS3     | 0.015198 | 1.5198    |
# | 14   | Gene_SYDE1     | 0.014925 | 1.4925    |
# | 15   | Gene_BHMT2     | 0.014302 | 1.4302    |
# | 16   | Gene_MAGI2-AS3 | 0.013946 | 1.3946    |
# | 17   | Gene_PRTFDC1   | 0.013617 | 1.3617    |
# | 18   | Gene_DKK3      | 0.013346 | 1.3346    |
# | 19   | Gene_NT5E      | 0.013196 | 1.3196    |
# | 20   | Gene_RBPMS     | 0.012874 | 1.2874    |
#
# ### Top 20 甲基化特征
#
# | 排名 | 特征名                | 权重     | 占比 (%) |
# |------|------------------------|----------|----------|
# | 1    | Methylation_cg24940138 | 0.002320 | 0.2320   |
# | 2    | Methylation_cg27539986 | 0.002138 | 0.2138   |
# | 3    | Methylation_cg15356923 | 0.002079 | 0.2079   |
# | 4    | Methylation_cg08047907 | 0.002006 | 0.2006   |
# | 5    | Methylation_cg21523564 | 0.001810 | 0.1810   |
# | 6    | Methylation_cg03205103 | 0.001634 | 0.1634   |
# | 7    | Methylation_cg17415451 | 0.001615 | 0.1615   |
# | 8    | Methylation_cg19505129 | 0.001561 | 0.1561   |
# | 9    | Methylation_cg19310908 | 0.001522 | 0.1523   |
# | 10   | Methylation_cg08857063 | 0.001491 | 0.1491   |
# | 11   | Methylation_cg21038156 | 0.001470 | 0.1470   |
# | 12   | Methylation_cg06954520 | 0.001446 | 0.1446   |
# | 13   | Methylation_cg05559795 | 0.001401 | 0.1401   |
# | 14   | Methylation_cg15229275 | 0.001380 | 0.1380   |
# | 15   | Methylation_cg14928057 | 0.001368 | 0.1368   |
# | 16   | Methylation_cg23200020 | 0.001333 | 0.1333   |
# | 17   | Methylation_cg26010734 | 0.001259 | 0.1259   |
# | 18   | Methylation_cg02773086 | 0.001250 | 0.1250   |
# | 19   | Methylation_cg24180402 | 0.001244 | 0.1244   |
# | 20   | Methylation_cg01367393 | 0.001189 | 0.1189   |
#
# ---
#
# ## 7. 测试集性能评估
#
# | 指标     | 数值     |
# |----------|----------|
# | 准确率   | 0.9091   |
# | 精确率   | 0.9556   |
# | 召回率   | 0.8600   |
# | F1 分数  | 0.9053   |
# | AUC      | 0.9669   |
#
# **混淆矩阵**：
#
# |               | 预测 Low | 预测 High |
# |---------------|----------|-----------|
# | 实际 Low      | 47       | 2         |
# | 实际 High     | 7        | 43        |
#
# ---
#
# ## 8. 交叉验证结果（5折）
#
# | Fold | 准确率 | 精确率 | 召回率 | F1分数 | AUC    |
# |------|--------|--------|--------|--------|--------|
# | 1    | 0.8889 | 0.8958 | 0.8776 | 0.8866 | 0.9559 |
# | 2    | 0.8990 | 0.8980 | 0.8980 | 0.8980 | 0.9776 |
# | 3    | 0.8889 | 0.8305 | 0.9800 | 0.8991 | 0.9771 |
# | 4    | 0.8586 | 0.9091 | 0.8000 | 0.8511 | 0.9682 |
# | 5    | 0.9091 | 0.9184 | 0.9000 | 0.9091 | 0.9747 |
#
# **平均性能**：
#
# | 指标     | 数值   |
# |----------|--------|
# | 平均准确率 | 0.8889 |
# | 平均精确率 | 0.8904 |
# | 平均召回率 | 0.8911 |
# | 平均F1分数 | 0.8888 |
# | 平均AUC    | 0.9707 |
#
# ---

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import VarianceThreshold, f_classif, SelectKBest
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
import warnings

# 忽略警告
warnings.filterwarnings('ignore')

# 设置路径
input_dir = '/Users/heweilin/Desktop/M-28-SKCM/NTU_DATA_CLEANED/'
output_dir = '/Users/heweilin/Desktop/M-28-SKCM/SKCM_Model/Random_Forest/'

# 确保输出目录存在
os.makedirs(output_dir, exist_ok=True)

# 加载数据
print("加载数据...")
# MIR100HG表达水平数据
mir_exp = pd.read_csv(os.path.join(input_dir, 'SKCM_Model_MIR100HG_Expression_Levels.csv'))
# 基因表达数据
gene_exp = pd.read_csv(os.path.join(input_dir, 'SKCM_Model_Gene_Expression_Features.csv'))
# 甲基化数据
methylation = pd.read_csv(os.path.join(input_dir, 'SKCM_Model_Methylation_Features.csv'))

print("MIR100HG表达数据形状:", mir_exp.shape)
print("基因表达数据形状:", gene_exp.shape)
print("甲基化数据形状:", methylation.shape)

# 数据预处理
print("\n数据预处理...")

# 提取标签
y_data = mir_exp[['Sample_ID', 'Group']]
y_data['Group'] = y_data['Group'].map({'High': 1, 'Low': 0})

# 处理基因表达数据
print("\n处理基因表达数据...")
gene_exp_pivot = gene_exp.copy()

# 检查是否存在MIR100HG基因，并将其从特征中删除
if 'MIR100HG' in gene_exp_pivot.index:
    print("检测到MIR100HG基因，将其从特征中删除...")
    gene_exp_pivot = gene_exp_pivot.drop('MIR100HG', axis=0)

gene_exp_pivot = gene_exp_pivot.set_index('HGNC_Symbol')
gene_exp_pivot = gene_exp_pivot.transpose()
gene_exp_pivot = gene_exp_pivot.reset_index()
gene_exp_pivot = gene_exp_pivot.rename(columns={'index': 'Sample_ID'})

# 处理甲基化数据
print("\n处理甲基化数据...")
methylation_pivot = methylation.copy()
methylation_pivot = methylation_pivot.set_index('Probe_ID')
methylation_pivot = methylation_pivot.transpose()
methylation_pivot = methylation_pivot.reset_index()
methylation_pivot = methylation_pivot.rename(columns={'index': 'Sample_ID'})

# 合并数据
print("\n合并数据...")
# 先合并MIR和基因表达
tmp_merged = y_data.merge(gene_exp_pivot, on='Sample_ID', how='inner')
print(f"MIR和基因表达合并后的形状: {tmp_merged.shape}")

# 然后合并甲基化数据
merged_data = tmp_merged.merge(methylation_pivot, on='Sample_ID', how='inner')
print(f"加入甲基化数据后的形状: {merged_data.shape}")

# 检查合并后的数据
if merged_data.shape[0] == 0:
    print("警告: 合并后的数据为空! 检查Sample_ID是否匹配。")
    import sys
    sys.exit(1)

print(f"合并后的数据形状: {merged_data.shape}")
print(f"样本数量: {merged_data.shape[0]}")
print(f"特征数量 (包括Sample_ID和Group): {merged_data.shape[1]}")

# 分割数据为X和y
X = merged_data.drop(['Sample_ID', 'Group'], axis=1)
y = merged_data['Group']
sample_ids = merged_data['Sample_ID']

# 为特征添加前缀
gene_features = gene_exp_pivot.columns.tolist()[1:]  # 跳过Sample_ID
methylation_features = methylation_pivot.columns.tolist()[1:]  # 跳过Sample_ID

gene_prefix = {feature: f"Gene_{feature}" for feature in gene_features}
methylation_prefix = {feature: f"Methylation_{feature}" for feature in methylation_features}

# 重命名列
X = X.rename(columns={**gene_prefix, **methylation_prefix})

print(f"\n添加前缀后的特征数量: {X.shape[1]}")
print(f"基因表达特征数量: {len(gene_features)}")
print(f"甲基化特征数量: {len(methylation_features)}")

# 确保MIR100HG相关特征被删除
mir100hg_cols = [col for col in X.columns if 'MIR100HG' in col]
if len(mir100hg_cols) > 0:
    print(f"删除以下MIR100HG相关特征: {mir100hg_cols}")
    X = X.drop(mir100hg_cols, axis=1)

# 获取基因表达和甲基化特征的列
gene_columns = [col for col in X.columns if col.startswith('Gene_')]
methylation_columns = [col for col in X.columns if col.startswith('Methylation_')]

# 划分训练集和测试集
print("\n划分训练集和测试集...")
X_train, X_test, y_train, y_test, ids_train, ids_test = train_test_split(
    X, y, sample_ids, test_size=0.2, random_state=42, stratify=y
)

print(f"训练集样本数: {X_train.shape[0]}")
print(f"测试集样本数: {X_test.shape[0]}")

# 特征选择函数 - 分别为基因表达和甲基化数据进行特征选择
def select_features(X_train, y_train, var_threshold=0.005, k_gene=200, k_meth=100):
    # 分离基因表达和甲基化特征
    X_train_gene = X_train[gene_columns]
    X_train_meth = X_train[methylation_columns]
    
    print("特征选择前:")
    print(f"总特征数量: {X_train.shape[1]}")
    print(f"基因表达特征数量: {X_train_gene.shape[1]}")
    print(f"甲基化特征数量: {X_train_meth.shape[1]}")
    
    # 1. 对基因表达特征进行方差过滤
    selector_var_gene = VarianceThreshold(threshold=var_threshold)
    X_train_gene_var = selector_var_gene.fit_transform(X_train_gene)
    gene_var_features = X_train_gene.columns[selector_var_gene.get_support()].tolist()
    print(f"方差过滤后的基因表达特征数量: {len(gene_var_features)}")
    
    # 2. 对甲基化特征进行方差过滤
    selector_var_meth = VarianceThreshold(threshold=var_threshold)
    X_train_meth_var = selector_var_meth.fit_transform(X_train_meth)
    meth_var_features = X_train_meth.columns[selector_var_meth.get_support()].tolist()
    print(f"方差过滤后的甲基化特征数量: {len(meth_var_features)}")
    
    # 3. 对基因表达特征进行ANOVA F检验
    X_train_gene_var_df = pd.DataFrame(X_train_gene_var, columns=gene_var_features, index=X_train.index)
    k_gene_actual = min(k_gene, X_train_gene_var_df.shape[1])
    selector_f_gene = SelectKBest(f_classif, k=k_gene_actual)
    _ = selector_f_gene.fit_transform(X_train_gene_var_df, y_train)
    gene_selected_features = X_train_gene_var_df.columns[selector_f_gene.get_support()].tolist()
    print(f"ANOVA选择后的基因表达特征数量: {len(gene_selected_features)}")
    
    # 4. 对甲基化特征进行ANOVA F检验
    X_train_meth_var_df = pd.DataFrame(X_train_meth_var, columns=meth_var_features, index=X_train.index)
    k_meth_actual = min(k_meth, X_train_meth_var_df.shape[1])
    selector_f_meth = SelectKBest(f_classif, k=k_meth_actual)
    _ = selector_f_meth.fit_transform(X_train_meth_var_df, y_train)
    meth_selected_features = X_train_meth_var_df.columns[selector_f_meth.get_support()].tolist()
    print(f"ANOVA选择后的甲基化特征数量: {len(meth_selected_features)}")
    
    # 合并所选特征
    all_selected_features = gene_selected_features + meth_selected_features
    print(f"合并后的所选特征总数: {len(all_selected_features)}")
    print(f"基因表达特征: {len(gene_selected_features)}")
    print(f"甲基化特征: {len(meth_selected_features)}")
    
    # 创建选择矩阵
    combined_support = np.zeros(X_train.shape[1], dtype=bool)
    for i, feature in enumerate(X_train.columns):
        if feature in all_selected_features:
            combined_support[i] = True
    
    return combined_support, all_selected_features

# 使用训练集进行特征选择
print("\n在训练集上进行特征选择...")
feature_support, selected_features = select_features(X_train, y_train)

# 应用特征选择
X_train_selected = X_train.loc[:, feature_support]
X_test_selected = X_test.loc[:, feature_support]

print(f"选择后的特征数量: {X_train_selected.shape[1]}")
print("选择的基因表达特征数量:", len([f for f in X_train_selected.columns if f.startswith('Gene_')]))
print("选择的甲基化特征数量:", len([f for f in X_train_selected.columns if f.startswith('Methylation_')]))

# 特征重要性分析
def feature_importance_analysis(model, X, feature_names):
    # 获取特征重要性
    importances = model.feature_importances_
    
    # 创建一个DataFrame来存储特征重要性
    feature_importance_df = pd.DataFrame({
        'Feature': feature_names,
        'Importance': importances
    })
    
    # 按重要性排序
    feature_importance_df = feature_importance_df.sort_values('Importance', ascending=False)
    
    # 计算百分比
    feature_importance_df['Percentage'] = feature_importance_df['Importance'] / feature_importance_df['Importance'].sum() * 100
    
    return feature_importance_df

# 训练随机森林模型
print("\n训练随机森林模型...")
rf_model = RandomForestClassifier(
    n_estimators=100,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    random_state=42,
    n_jobs=-1
)

rf_model.fit(X_train_selected, y_train)

# 分析特征重要性
print("\n特征重要性分析...")
feature_importance = feature_importance_analysis(rf_model, X_train_selected, X_train_selected.columns)

# 分类特征并计算每类特征的总重要性
gene_importance = feature_importance[feature_importance['Feature'].str.startswith('Gene_')]
methylation_importance = feature_importance[feature_importance['Feature'].str.startswith('Methylation_')]

gene_importance_sum = gene_importance['Importance'].sum()
methylation_importance_sum = methylation_importance['Importance'].sum()
total_importance = gene_importance_sum + methylation_importance_sum

# 打印特征重要性统计
print("\n特征重要性百分比:")
print(f"基因表达特征: {gene_importance_sum / total_importance * 100:.2f}%")
print(f"甲基化特征: {methylation_importance_sum / total_importance * 100:.2f}%")

# 打印按类别分组的Top20特征
print("\n基因表达Top20特征:")
print(gene_importance.head(20).to_string(index=False))

print("\n甲基化Top20特征:")
print(methylation_importance.head(20).to_string(index=False))

print("\n总体Top20特征:")
print(feature_importance.head(20).to_string(index=False))

# 保存特征重要性结果
gene_importance.to_csv(os.path.join(output_dir, 'SKCM_Random_Forest_Gene_Importance.csv'), index=False)
methylation_importance.to_csv(os.path.join(output_dir, 'SKCM_Random_Forest_Methylation_Importance.csv'), index=False)
feature_importance.to_csv(os.path.join(output_dir, 'SKCM_Random_Forest_All_Features_Importance.csv'), index=False)

# 在测试集上评估模型
print("\n在测试集上评估模型...")
y_pred = rf_model.predict(X_test_selected)
y_prob = rf_model.predict_proba(X_test_selected)[:, 1]

# 计算指标
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_prob)
cm = confusion_matrix(y_test, y_pred)

# 打印评估结果
print("\n测试集性能指标:")
print(f"准确率 (Accuracy): {accuracy:.4f}")
print(f"精确率 (Precision): {precision:.4f}")
print(f"召回率 (Recall): {recall:.4f}")
print(f"F1分数: {f1:.4f}")
print(f"AUC: {auc:.4f}")
print("混淆矩阵:")
print(cm)

# 保存模型性能指标
with open(os.path.join(output_dir, 'SKCM_RandomForest_Model_Performance.txt'), 'w') as f:
    f.write(f"测试集性能指标:\n")
    f.write(f"准确率 (Accuracy): {accuracy:.4f}\n")
    f.write(f"精确率 (Precision): {precision:.4f}\n")
    f.write(f"召回率 (Recall): {recall:.4f}\n")
    f.write(f"F1分数: {f1:.4f}\n")
    f.write(f"AUC: {auc:.4f}\n")
    f.write("混淆矩阵:\n")
    f.write(f"{cm[0][0]} {cm[0][1]}\n")
    f.write(f"{cm[1][0]} {cm[1][1]}\n")

# 交叉验证
print("\n执行交叉验证...")
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

cv_results = {
    'fold': [],
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1': [],
    'auc': []
}

fold = 1
for train_idx, val_idx in skf.split(X, y):
    print(f"\n执行第{fold}折交叉验证...")
    
    # 获取当前fold的训练和验证数据
    X_fold_train, X_fold_val = X.iloc[train_idx], X.iloc[val_idx]
    y_fold_train, y_fold_val = y.iloc[train_idx], y.iloc[val_idx]
    
    # 在fold内进行特征选择
    print(f"Fold {fold} - 特征选择...")
    fold_feature_support, fold_selected_features = select_features(X_fold_train, y_fold_train)
    
    # 应用特征选择
    X_fold_train_selected = X_fold_train.loc[:, fold_feature_support]
    X_fold_val_selected = X_fold_val.loc[:, fold_feature_support]
    
    # 训练模型
    print(f"Fold {fold} - 训练模型...")
    fold_model = RandomForestClassifier(
        n_estimators=100,
        max_depth=None,
        min_samples_split=2,
        min_samples_leaf=1,
        random_state=42,
        n_jobs=-1
    )
    fold_model.fit(X_fold_train_selected, y_fold_train)
    
    # 预测
    y_fold_pred = fold_model.predict(X_fold_val_selected)
    y_fold_prob = fold_model.predict_proba(X_fold_val_selected)[:, 1]
    
    # 计算性能指标
    fold_accuracy = accuracy_score(y_fold_val, y_fold_pred)
    fold_precision = precision_score(y_fold_val, y_fold_pred)
    fold_recall = recall_score(y_fold_val, y_fold_pred)
    fold_f1 = f1_score(y_fold_val, y_fold_pred)
    fold_auc = roc_auc_score(y_fold_val, y_fold_prob)
    
    # 打印本折结果
    print(f"Fold {fold} - 性能指标:")
    print(f"  准确率: {fold_accuracy:.4f}")
    print(f"  精确率: {fold_precision:.4f}")
    print(f"  召回率: {fold_recall:.4f}")
    print(f"  F1分数: {fold_f1:.4f}")
    print(f"  AUC: {fold_auc:.4f}")
    
    # 保存结果
    cv_results['fold'].append(fold)
    cv_results['accuracy'].append(fold_accuracy)
    cv_results['precision'].append(fold_precision)
    cv_results['recall'].append(fold_recall)
    cv_results['f1'].append(fold_f1)
    cv_results['auc'].append(fold_auc)
    
    # 分析特征重要性
    fold_importance = feature_importance_analysis(fold_model, X_fold_train_selected, X_fold_train_selected.columns)
    
    # 保存本折的特征重要性
    fold_importance.to_csv(os.path.join(output_dir, f'PRAD_RandomForest_Fold{fold}_Feature_Importance.csv'), index=False)
    
    fold += 1

# 计算交叉验证的平均性能
cv_results_df = pd.DataFrame(cv_results)
cv_mean = cv_results_df.mean()

print("\n交叉验证平均性能:")
print(f"平均准确率: {cv_mean['accuracy']:.4f}")
print(f"平均精确率: {cv_mean['precision']:.4f}")
print(f"平均召回率: {cv_mean['recall']:.4f}")
print(f"平均F1分数: {cv_mean['f1']:.4f}")
print(f"平均AUC: {cv_mean['auc']:.4f}")

# 保存交叉验证结果
cv_results_df.to_csv(os.path.join(output_dir, 'SKCM_Random_Forest_CV_Results.csv'), index=False)

print("\n分析完成！所有结果已保存到:", output_dir)
# Out:
# 加载数据...
# MIR100HG表达数据形状: (102, 4)
# 基因表达数据形状: (3828, 103)
# 甲基化数据形状: (191, 475)
#
# 数据预处理...
#
# 处理基因表达数据...
#
# 处理甲基化数据...
#
# 合并数据...
# MIR和基因表达合并后的形状: (102, 3830)
# 加入甲基化数据后的形状: (102, 4021)
# 合并后的数据形状: (102, 4021)
# 样本数量: 102
# 特征数量 (包括Sample_ID和Group): 4021
#
# 添加前缀后的特征数量: 4019
# 基因表达特征数量: 3828
# 甲基化特征数量: 191
# 删除以下MIR100HG相关特征: ['Gene_MIR100HG']
#
# 划分训练集和测试集...
# 训练集样本数: 81
# 测试集样本数: 21
#
# 在训练集上进行特征选择...
# 特征选择前:
# 总特征数量: 4018
# 基因表达特征数量: 3829
# 甲基化特征数量: 191
# 方差过滤后的基因表达特征数量: 3829
# 方差过滤后的甲基化特征数量: 191
# ANOVA选择后的基因表达特征数量: 200
# ANOVA选择后的甲基化特征数量: 100
# 合并后的所选特征总数: 300
# 基因表达特征: 200
# 甲基化特征: 100
# 选择后的特征数量: 300
# 选择的基因表达特征数量: 200
# 选择的甲基化特征数量: 100
#
# 训练随机森林模型...
#
# 特征重要性分析...
#
# 特征重要性百分比:
# 基因表达特征: 70.05%
# 甲基化特征: 29.95%
#
# 基因表达Top20特征:
#       Feature  Importance  Percentage
#     Gene_WNK4    0.023175    2.317479
#   Gene_SPPL2B    0.021658    2.165787
#    Gene_LAMA4    0.020181    2.018063
#    Gene_FLRT1    0.019250    1.924969
#    Gene_AKAP6    0.018675    1.867482
#    Gene_TRIM9    0.017417    1.741700
#    Gene_RBMS3    0.016675    1.667492
#   Gene_MFAP3L    0.016642    1.664169
#    Gene_FHDC1    0.014970    1.496978
#    Gene_XYLT1    0.014054    1.405411
#      Gene_LBH    0.013653    1.365282
#   Gene_PIK3CD    0.012501    1.250106
# Gene_MAP3K7CL    0.012072    1.207197
#     Gene_BMP6    0.011972    1.197198
#   Gene_ELOVL2    0.011611    1.161079
#    Gene_ENPEP    0.011558    1.155793
#    Gene_PDGFA    0.010961    1.096104
#  Gene_GOLGA7B    0.010133    1.013267
# Gene_CSPG4P12    0.010057    1.005728
#     Gene_LGI4    0.009681    0.968095
#
# 甲基化Top20特征:
#                Feature  Importance  Percentage
# Methylation_cg06294470    0.015847    1.584674
# Methylation_cg19225602    0.015209    1.520934
# Methylation_cg12167489    0.014971    1.497129
# Methylation_cg08788712    0.014682    1.468232
# Methylation_cg22683277    0.013858    1.385770
# Methylation_cg23908638    0.012546    1.254552
# Methylation_cg07376732    0.009967    0.996673
# Methylation_cg04982488    0.008913    0.891314
# Methylation_cg14195115    0.007558    0.755844
# Methylation_cg04697299    0.007342    0.734208
# Methylation_cg07482257    0.007230    0.723005
# Methylation_cg18977283    0.007107    0.710723
# Methylation_cg15405572    0.007079    0.707905
# Methylation_cg02572796    0.007075    0.707516
# Methylation_cg07799299    0.006978    0.697832
# Methylation_cg11234339    0.006959    0.695946
# Methylation_cg00685984    0.006605    0.660452
# Methylation_cg25364619    0.006591    0.659072
# Methylation_cg00445755    0.006398    0.639831
# Methylation_cg09749364    0.006264    0.626400
#
# 总体Top20特征:
#                Feature  Importance  Percentage
#              Gene_WNK4    0.023175    2.317479
#            Gene_SPPL2B    0.021658    2.165787
#             Gene_LAMA4    0.020181    2.018063
#             Gene_FLRT1    0.019250    1.924969
#             Gene_AKAP6    0.018675    1.867482
#             Gene_TRIM9    0.017417    1.741700
#             Gene_RBMS3    0.016675    1.667492
#            Gene_MFAP3L    0.016642    1.664169
# Methylation_cg06294470    0.015847    1.584674
# Methylation_cg19225602    0.015209    1.520934
# Methylation_cg12167489    0.014971    1.497129
#             Gene_FHDC1    0.014970    1.496978
# Methylation_cg08788712    0.014682    1.468232
#             Gene_XYLT1    0.014054    1.405411
# Methylation_cg22683277    0.013858    1.385770
#               Gene_LBH    0.013653    1.365282
# Methylation_cg23908638    0.012546    1.254552
#            Gene_PIK3CD    0.012501    1.250106
#          Gene_MAP3K7CL    0.012072    1.207197
#              Gene_BMP6    0.011972    1.197198
#
# 在测试集上评估模型...
#
# 测试集性能指标:
# 准确率 (Accuracy): 0.8571
# 精确率 (Precision): 1.0000
# 召回率 (Recall): 0.7000
# F1分数: 0.8235
# AUC: 0.9273
# 混淆矩阵:
# [[11  0]
#  [ 3  7]]
#
# 执行交叉验证...
#
# 执行第1折交叉验证...
# Fold 1 - 特征选择...
# 特征选择前:
# 总特征数量: 4018
# 基因表达特征数量: 3829
# 甲基化特征数量: 191
# 方差过滤后的基因表达特征数量: 3829
# 方差过滤后的甲基化特征数量: 191
# ANOVA选择后的基因表达特征数量: 200
# ANOVA选择后的甲基化特征数量: 100
# 合并后的所选特征总数: 300
# 基因表达特征: 200
# 甲基化特征: 100
# Fold 1 - 训练模型...
# Fold 1 - 性能指标:
#   准确率: 0.8571
#   精确率: 0.8182
#   召回率: 0.9000
#   F1分数: 0.8571
#   AUC: 0.9545
#
# 执行第2折交叉验证...
# Fold 2 - 特征选择...
# 特征选择前:
# 总特征数量: 4018
# 基因表达特征数量: 3829
# 甲基化特征数量: 191
# 方差过滤后的基因表达特征数量: 3829
# 方差过滤后的甲基化特征数量: 191
# ANOVA选择后的基因表达特征数量: 200
# ANOVA选择后的甲基化特征数量: 100
# 合并后的所选特征总数: 300
# 基因表达特征: 200
# 甲基化特征: 100
# Fold 2 - 训练模型...
# Fold 2 - 性能指标:
#   准确率: 0.9524
#   精确率: 1.0000
#   召回率: 0.9091
#   F1分数: 0.9524
#   AUC: 0.9409
#
# 执行第3折交叉验证...
# Fold 3 - 特征选择...
# 特征选择前:
# 总特征数量: 4018
# 基因表达特征数量: 3829
# 甲基化特征数量: 191
# 方差过滤后的基因表达特征数量: 3829
# 方差过滤后的甲基化特征数量: 191
# ANOVA选择后的基因表达特征数量: 200
# ANOVA选择后的甲基化特征数量: 100
# 合并后的所选特征总数: 300
# 基因表达特征: 200
# 甲基化特征: 100
# Fold 3 - 训练模型...
# Fold 3 - 性能指标:
#   准确率: 0.9500
#   精确率: 1.0000
#   召回率: 0.9000
#   F1分数: 0.9474
#   AUC: 0.9600
#
# 执行第4折交叉验证...
# Fold 4 - 特征选择...
# 特征选择前:
# 总特征数量: 4018
# 基因表达特征数量: 3829
# 甲基化特征数量: 191
# 方差过滤后的基因表达特征数量: 3829
# 方差过滤后的甲基化特征数量: 191
# ANOVA选择后的基因表达特征数量: 200
# ANOVA选择后的甲基化特征数量: 100
# 合并后的所选特征总数: 300
# 基因表达特征: 200
# 甲基化特征: 100
# Fold 4 - 训练模型...
# Fold 4 - 性能指标:
#   准确率: 0.7500
#   精确率: 0.6923
#   召回率: 0.9000
#   F1分数: 0.7826
#   AUC: 0.9300
#
# 执行第5折交叉验证...
# Fold 5 - 特征选择...
# 特征选择前:
# 总特征数量: 4018
# 基因表达特征数量: 3829
# 甲基化特征数量: 191
# 方差过滤后的基因表达特征数量: 3829
# 方差过滤后的甲基化特征数量: 191
# ANOVA选择后的基因表达特征数量: 200
# ANOVA选择后的甲基化特征数量: 100
# 合并后的所选特征总数: 300
# 基因表达特征: 200
# 甲基化特征: 100
# Fold 5 - 训练模型...
# Fold 5 - 性能指标:
#   准确率: 0.7500
#   精确率: 0.6923
#   召回率: 0.9000
#   F1分数: 0.7826
#   AUC: 0.9500
#
# 交叉验证平均性能:
# 平均准确率: 0.8519
# 平均精确率: 0.8406
# 平均召回率: 0.9018
# 平均F1分数: 0.8644
# 平均AUC: 0.9471
#
# 分析完成！所有结果已保存到: /Users/heweilin/Desktop/M-28-SKCM/SKCM_Model/Random_Forest/

# %% [markdown]
# # Processing_Initial_Data

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import VarianceThreshold, f_classif, SelectKBest
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
import warnings

# 忽略警告
warnings.filterwarnings('ignore')

# 设置路径
input_dir = '/Users/heweilin/Desktop/M-28-SKCM/NTU_DATA_CLEANED/'

# 确保输出目录存在
os.makedirs(output_dir, exist_ok=True)

# 加载数据
print("加载数据...")
# MIR100HG表达水平数据
mir_exp = pd.read_csv(os.path.join(input_dir, 'SKCM_Model_MIR100HG_Expression_Levels.csv'))
# 基因表达数据
gene_exp = pd.read_csv(os.path.join(input_dir, 'SKCM_Model_Gene_Expression_Features_Test.csv'))
# 甲基化数据
methylation = pd.read_csv(os.path.join(input_dir, 'SKCM_Model_Methylation_Features_Test.csv'))

print("MIR100HG表达数据形状:", mir_exp.shape)
print("基因表达数据形状:", gene_exp.shape)
print("甲基化数据形状:", methylation.shape)

# 数据预处理
print("\n数据预处理...")

# 提取标签
y_data = mir_exp[['Sample_ID', 'Group']]
y_data['Group'] = y_data['Group'].map({'High': 1, 'Low': 0})

# 处理基因表达数据
print("\n处理基因表达数据...")
gene_exp_pivot = gene_exp.copy()

# 检查是否存在MIR100HG基因，并将其从特征中删除
if 'MIR100HG' in gene_exp_pivot.index:
    print("检测到MIR100HG基因，将其从特征中删除...")
    gene_exp_pivot = gene_exp_pivot.drop('MIR100HG', axis=0)

gene_exp_pivot = gene_exp_pivot.set_index('HGNC_Symbol')
gene_exp_pivot = gene_exp_pivot.transpose()
gene_exp_pivot = gene_exp_pivot.reset_index()
gene_exp_pivot = gene_exp_pivot.rename(columns={'index': 'Sample_ID'})

# 处理甲基化数据
print("\n处理甲基化数据...")
methylation_pivot = methylation.copy()
methylation_pivot = methylation_pivot.set_index('Probe_ID')
methylation_pivot = methylation_pivot.transpose()
methylation_pivot = methylation_pivot.reset_index()
methylation_pivot = methylation_pivot.rename(columns={'index': 'Sample_ID'})

# 合并数据
print("\n合并数据...")
# 先合并MIR和基因表达
tmp_merged = y_data.merge(gene_exp_pivot, on='Sample_ID', how='inner')
print(f"MIR和基因表达合并后的形状: {tmp_merged.shape}")

# 然后合并甲基化数据
merged_data = tmp_merged.merge(methylation_pivot, on='Sample_ID', how='inner')
print(f"加入甲基化数据后的形状: {merged_data.shape}")

# 检查合并后的数据
if merged_data.shape[0] == 0:
    print("警告: 合并后的数据为空! 检查Sample_ID是否匹配。")
    import sys
    sys.exit(1)

print(f"合并后的数据形状: {merged_data.shape}")
print(f"样本数量: {merged_data.shape[0]}")
print(f"特征数量 (包括Sample_ID和Group): {merged_data.shape[1]}")

# 分割数据为X和y
X = merged_data.drop(['Sample_ID', 'Group'], axis=1)
y = merged_data['Group']
sample_ids = merged_data['Sample_ID']

# 为特征添加前缀
gene_features = gene_exp_pivot.columns.tolist()[1:]  # 跳过Sample_ID
methylation_features = methylation_pivot.columns.tolist()[1:]  # 跳过Sample_ID

gene_prefix = {feature: f"Gene_{feature}" for feature in gene_features}
methylation_prefix = {feature: f"Methylation_{feature}" for feature in methylation_features}

# 重命名列
X = X.rename(columns={**gene_prefix, **methylation_prefix})

print(f"\n添加前缀后的特征数量: {X.shape[1]}")
print(f"基因表达特征数量: {len(gene_features)}")
print(f"甲基化特征数量: {len(methylation_features)}")

# 确保MIR100HG相关特征被删除
mir100hg_cols = [col for col in X.columns if 'MIR100HG' in col]
if len(mir100hg_cols) > 0:
    print(f"删除以下MIR100HG相关特征: {mir100hg_cols}")
    X = X.drop(mir100hg_cols, axis=1)

# 获取基因表达和甲基化特征的列
gene_columns = [col for col in X.columns if col.startswith('Gene_')]
methylation_columns = [col for col in X.columns if col.startswith('Methylation_')]

# 划分训练集和测试集
print("\n划分训练集和测试集...")
X_train, X_test, y_train, y_test, ids_train, ids_test = train_test_split(
    X, y, sample_ids, test_size=0.2, random_state=42, stratify=y
)

print(f"训练集样本数: {X_train.shape[0]}")
print(f"测试集样本数: {X_test.shape[0]}")

# 特征选择函数 - 分别为基因表达和甲基化数据进行特征选择
def select_features(X_train, y_train, var_threshold=0.005, k_gene=200, k_meth=100):
    # 分离基因表达和甲基化特征
    X_train_gene = X_train[gene_columns]
    X_train_meth = X_train[methylation_columns]
    
    print("特征选择前:")
    print(f"总特征数量: {X_train.shape[1]}")
    print(f"基因表达特征数量: {X_train_gene.shape[1]}")
    print(f"甲基化特征数量: {X_train_meth.shape[1]}")
    
    # 1. 对基因表达特征进行方差过滤
    selector_var_gene = VarianceThreshold(threshold=var_threshold)
    X_train_gene_var = selector_var_gene.fit_transform(X_train_gene)
    gene_var_features = X_train_gene.columns[selector_var_gene.get_support()].tolist()
    print(f"方差过滤后的基因表达特征数量: {len(gene_var_features)}")
    
    # 2. 对甲基化特征进行方差过滤
    selector_var_meth = VarianceThreshold(threshold=var_threshold)
    X_train_meth_var = selector_var_meth.fit_transform(X_train_meth)
    meth_var_features = X_train_meth.columns[selector_var_meth.get_support()].tolist()
    print(f"方差过滤后的甲基化特征数量: {len(meth_var_features)}")
    
    # 3. 对基因表达特征进行ANOVA F检验
    X_train_gene_var_df = pd.DataFrame(X_train_gene_var, columns=gene_var_features, index=X_train.index)
    k_gene_actual = min(k_gene, X_train_gene_var_df.shape[1])
    selector_f_gene = SelectKBest(f_classif, k=k_gene_actual)
    _ = selector_f_gene.fit_transform(X_train_gene_var_df, y_train)
    gene_selected_features = X_train_gene_var_df.columns[selector_f_gene.get_support()].tolist()
    print(f"ANOVA选择后的基因表达特征数量: {len(gene_selected_features)}")
    
    # 4. 对甲基化特征进行ANOVA F检验
    X_train_meth_var_df = pd.DataFrame(X_train_meth_var, columns=meth_var_features, index=X_train.index)
    k_meth_actual = min(k_meth, X_train_meth_var_df.shape[1])
    selector_f_meth = SelectKBest(f_classif, k=k_meth_actual)
    _ = selector_f_meth.fit_transform(X_train_meth_var_df, y_train)
    meth_selected_features = X_train_meth_var_df.columns[selector_f_meth.get_support()].tolist()
    print(f"ANOVA选择后的甲基化特征数量: {len(meth_selected_features)}")
    
    # 合并所选特征
    all_selected_features = gene_selected_features + meth_selected_features
    print(f"合并后的所选特征总数: {len(all_selected_features)}")
    print(f"基因表达特征: {len(gene_selected_features)}")
    print(f"甲基化特征: {len(meth_selected_features)}")
    
    # 创建选择矩阵
    combined_support = np.zeros(X_train.shape[1], dtype=bool)
    for i, feature in enumerate(X_train.columns):
        if feature in all_selected_features:
            combined_support[i] = True
    
    return combined_support, all_selected_features

# 使用训练集进行特征选择
print("\n在训练集上进行特征选择...")
feature_support, selected_features = select_features(X_train, y_train)

# 应用特征选择
X_train_selected = X_train.loc[:, feature_support]
X_test_selected = X_test.loc[:, feature_support]

print(f"选择后的特征数量: {X_train_selected.shape[1]}")
print("选择的基因表达特征数量:", len([f for f in X_train_selected.columns if f.startswith('Gene_')]))
print("选择的甲基化特征数量:", len([f for f in X_train_selected.columns if f.startswith('Methylation_')]))

# 特征重要性分析
def feature_importance_analysis(model, X, feature_names):
    # 获取特征重要性
    importances = model.feature_importances_
    
    # 创建一个DataFrame来存储特征重要性
    feature_importance_df = pd.DataFrame({
        'Feature': feature_names,
        'Importance': importances
    })
    
    # 按重要性排序
    feature_importance_df = feature_importance_df.sort_values('Importance', ascending=False)
    
    # 计算百分比
    feature_importance_df['Percentage'] = feature_importance_df['Importance'] / feature_importance_df['Importance'].sum() * 100
    
    return feature_importance_df

# 训练随机森林模型
print("\n训练随机森林模型...")
rf_model = RandomForestClassifier(
    n_estimators=100,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    random_state=42,
    n_jobs=-1
)

rf_model.fit(X_train_selected, y_train)

# 分析特征重要性
print("\n特征重要性分析...")
feature_importance = feature_importance_analysis(rf_model, X_train_selected, X_train_selected.columns)

# 分类特征并计算每类特征的总重要性
gene_importance = feature_importance[feature_importance['Feature'].str.startswith('Gene_')]
methylation_importance = feature_importance[feature_importance['Feature'].str.startswith('Methylation_')]

gene_importance_sum = gene_importance['Importance'].sum()
methylation_importance_sum = methylation_importance['Importance'].sum()
total_importance = gene_importance_sum + methylation_importance_sum

# 打印特征重要性统计
print("\n特征重要性百分比:")
print(f"基因表达特征: {gene_importance_sum / total_importance * 100:.2f}%")
print(f"甲基化特征: {methylation_importance_sum / total_importance * 100:.2f}%")

# 打印按类别分组的Top20特征
print("\n基因表达Top20特征:")
print(gene_importance.head(20).to_string(index=False))

print("\n甲基化Top20特征:")
print(methylation_importance.head(20).to_string(index=False))

print("\n总体Top20特征:")
print(feature_importance.head(20).to_string(index=False))


# 在测试集上评估模型
print("\n在测试集上评估模型...")
y_pred = rf_model.predict(X_test_selected)
y_prob = rf_model.predict_proba(X_test_selected)[:, 1]

# 计算指标
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_prob)
cm = confusion_matrix(y_test, y_pred)

# 打印评估结果
print("\n测试集性能指标:")
print(f"准确率 (Accuracy): {accuracy:.4f}")
print(f"精确率 (Precision): {precision:.4f}")
print(f"召回率 (Recall): {recall:.4f}")
print(f"F1分数: {f1:.4f}")
print(f"AUC: {auc:.4f}")
print("混淆矩阵:")
print(cm)

# 保存模型性能指标
with open(os.path.join(output_dir, 'SKCM_RandomForest_Model_Performance.txt'), 'w') as f:
    f.write(f"测试集性能指标:\n")
    f.write(f"准确率 (Accuracy): {accuracy:.4f}\n")
    f.write(f"精确率 (Precision): {precision:.4f}\n")
    f.write(f"召回率 (Recall): {recall:.4f}\n")
    f.write(f"F1分数: {f1:.4f}\n")
    f.write(f"AUC: {auc:.4f}\n")
    f.write("混淆矩阵:\n")
    f.write(f"{cm[0][0]} {cm[0][1]}\n")
    f.write(f"{cm[1][0]} {cm[1][1]}\n")

# 交叉验证
print("\n执行交叉验证...")
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

cv_results = {
    'fold': [],
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1': [],
    'auc': []
}

fold = 1
for train_idx, val_idx in skf.split(X, y):
    print(f"\n执行第{fold}折交叉验证...")
    
    # 获取当前fold的训练和验证数据
    X_fold_train, X_fold_val = X.iloc[train_idx], X.iloc[val_idx]
    y_fold_train, y_fold_val = y.iloc[train_idx], y.iloc[val_idx]
    
    # 在fold内进行特征选择
    print(f"Fold {fold} - 特征选择...")
    fold_feature_support, fold_selected_features = select_features(X_fold_train, y_fold_train)
    
    # 应用特征选择
    X_fold_train_selected = X_fold_train.loc[:, fold_feature_support]
    X_fold_val_selected = X_fold_val.loc[:, fold_feature_support]
    
    # 训练模型
    print(f"Fold {fold} - 训练模型...")
    fold_model = RandomForestClassifier(
        n_estimators=100,
        max_depth=None,
        min_samples_split=2,
        min_samples_leaf=1,
        random_state=42,
        n_jobs=-1
    )
    fold_model.fit(X_fold_train_selected, y_fold_train)
    
    # 预测
    y_fold_pred = fold_model.predict(X_fold_val_selected)
    y_fold_prob = fold_model.predict_proba(X_fold_val_selected)[:, 1]
    
    # 计算性能指标
    fold_accuracy = accuracy_score(y_fold_val, y_fold_pred)
    fold_precision = precision_score(y_fold_val, y_fold_pred)
    fold_recall = recall_score(y_fold_val, y_fold_pred)
    fold_f1 = f1_score(y_fold_val, y_fold_pred)
    fold_auc = roc_auc_score(y_fold_val, y_fold_prob)
    
    # 打印本折结果
    print(f"Fold {fold} - 性能指标:")
    print(f"  准确率: {fold_accuracy:.4f}")
    print(f"  精确率: {fold_precision:.4f}")
    print(f"  召回率: {fold_recall:.4f}")
    print(f"  F1分数: {fold_f1:.4f}")
    print(f"  AUC: {fold_auc:.4f}")
    
    # 保存结果
    cv_results['fold'].append(fold)
    cv_results['accuracy'].append(fold_accuracy)
    cv_results['precision'].append(fold_precision)
    cv_results['recall'].append(fold_recall)
    cv_results['f1'].append(fold_f1)
    cv_results['auc'].append(fold_auc)
    
    # 分析特征重要性
    fold_importance = feature_importance_analysis(fold_model, X_fold_train_selected, X_fold_train_selected.columns)
    
    # 保存本折的特征重要性
    fold_importance.to_csv(os.path.join(output_dir, f'SKCM_RandomForest_Fold{fold}_Feature_Importance.csv'), index=False)
    
    fold += 1

# 计算交叉验证的平均性能
cv_results_df = pd.DataFrame(cv_results)
cv_mean = cv_results_df.mean()

print("\n交叉验证平均性能:")
print(f"平均准确率: {cv_mean['accuracy']:.4f}")
print(f"平均精确率: {cv_mean['precision']:.4f}")
print(f"平均召回率: {cv_mean['recall']:.4f}")
print(f"平均F1分数: {cv_mean['f1']:.4f}")
print(f"平均AUC: {cv_mean['auc']:.4f}")
# Out:
# 加载数据...
# MIR100HG表达数据形状: (102, 4)
# 基因表达数据形状: (40060, 103)
# 甲基化数据形状: (373787, 475)
#
# 数据预处理...
#
# 处理基因表达数据...
#
# 处理甲基化数据...
#
# 合并数据...
# MIR和基因表达合并后的形状: (102, 40062)
# 加入甲基化数据后的形状: (102, 413849)
# 合并后的数据形状: (102, 413849)
# 样本数量: 102
# 特征数量 (包括Sample_ID和Group): 413849
#
# 添加前缀后的特征数量: 413847
# 基因表达特征数量: 40060
# 甲基化特征数量: 373787
# 删除以下MIR100HG相关特征: ['Gene_MIR100HG']
#
# 划分训练集和测试集...
# 训练集样本数: 81
# 测试集样本数: 21
#
# 在训练集上进行特征选择...
# 特征选择前:
# 总特征数量: 413846
# 基因表达特征数量: 40089
# 甲基化特征数量: 373787
# 方差过滤后的基因表达特征数量: 32147
# 方差过滤后的甲基化特征数量: 221666
# ANOVA选择后的基因表达特征数量: 200
# ANOVA选择后的甲基化特征数量: 100
# 合并后的所选特征总数: 300
# 基因表达特征: 200
# 甲基化特征: 100
# 选择后的特征数量: 300
# 选择的基因表达特征数量: 200
# 选择的甲基化特征数量: 100
#
# 训练随机森林模型...
#
# 特征重要性分析...
#
# 特征重要性百分比:
# 基因表达特征: 59.55%
# 甲基化特征: 40.45%
#
# 基因表达Top20特征:
#        Feature  Importance  Percentage
#     Gene_RBMS3    0.036268    3.626752
#     Gene_SNX22    0.033973    3.397263
#     Gene_LAMA4    0.030333    3.033297
#     Gene_RFTN2    0.028687    2.868699
#      Gene_WNK4    0.018737    1.873706
#     Gene_AKAP6    0.018617    1.861658
#     Gene_XYLT1    0.015621    1.562121
#    Gene_PHYKPL    0.015143    1.514341
#      Gene_LGI4    0.014004    1.400400
#     Gene_GPR37    0.013542    1.354225
#      Gene_BMP6    0.012237    1.223668
# Gene_LINC03013    0.011889    1.188918
#      Gene_FGF2    0.011307    1.130691
#      Gene_JPH1    0.009496    0.949649
#    Gene_ATP1B2    0.009208    0.920833
#     Gene_ITIH6    0.009096    0.909619
#    Gene_ELOVL2    0.008884    0.888381
#       Gene_HPN    0.008195    0.819545
#   Gene_GOLGA7B    0.008146    0.814600
#      Gene_EPN2    0.008034    0.803422
#
# 甲基化Top20特征:
#                     Feature  Importance  Percentage
#      Methylation_cg04982488    0.032776    3.277618
#      Methylation_cg15405572    0.021038    2.103784
# Methylation_ch.8.128185533F    0.017912    1.791244
#      Methylation_cg19225602    0.017123    1.712337
#      Methylation_cg22153312    0.013670    1.366995
#      Methylation_cg11234339    0.013618    1.361769
#      Methylation_cg20253105    0.013055    1.305528
#      Methylation_cg07799299    0.012566    1.256625
#      Methylation_cg14178043    0.011528    1.152800
#      Methylation_cg02372856    0.010469    1.046917
#      Methylation_cg06770878    0.010079    1.007900
#      Methylation_cg14422759    0.010017    1.001663
#      Methylation_cg18977283    0.009944    0.994356
#      Methylation_cg05860371    0.009758    0.975764
#      Methylation_cg14195115    0.009266    0.926582
#      Methylation_cg23908638    0.009042    0.904208
#      Methylation_cg06294470    0.008678    0.867832
#      Methylation_cg04145621    0.008204    0.820369
#      Methylation_cg05223396    0.008120    0.811959
#      Methylation_cg12918081    0.008081    0.808128
#
# 总体Top20特征:
#                     Feature  Importance  Percentage
#                  Gene_RBMS3    0.036268    3.626752
#                  Gene_SNX22    0.033973    3.397263
#      Methylation_cg04982488    0.032776    3.277618
#                  Gene_LAMA4    0.030333    3.033297
#                  Gene_RFTN2    0.028687    2.868699
#      Methylation_cg15405572    0.021038    2.103784
#                   Gene_WNK4    0.018737    1.873706
#                  Gene_AKAP6    0.018617    1.861658
# Methylation_ch.8.128185533F    0.017912    1.791244
#      Methylation_cg19225602    0.017123    1.712337
#                  Gene_XYLT1    0.015621    1.562121
#                 Gene_PHYKPL    0.015143    1.514341
#                   Gene_LGI4    0.014004    1.400400
#      Methylation_cg22153312    0.013670    1.366995
#      Methylation_cg11234339    0.013618    1.361769
#                  Gene_GPR37    0.013542    1.354225
#      Methylation_cg20253105    0.013055    1.305528
#      Methylation_cg07799299    0.012566    1.256625
#                   Gene_BMP6    0.012237    1.223668
#              Gene_LINC03013    0.011889    1.188918
#
# 在测试集上评估模型...
#
# 测试集性能指标:
# 准确率 (Accuracy): 0.8571
# 精确率 (Precision): 1.0000
# 召回率 (Recall): 0.7000
# F1分数: 0.8235
# AUC: 0.9045
# 混淆矩阵:
# [[11  0]
#  [ 3  7]]
#
# 执行交叉验证...
#
# 执行第1折交叉验证...
# Fold 1 - 特征选择...
# 特征选择前:
# 总特征数量: 413846
# 基因表达特征数量: 40089
# 甲基化特征数量: 373787
# 方差过滤后的基因表达特征数量: 32589
# 方差过滤后的甲基化特征数量: 227051
# ANOVA选择后的基因表达特征数量: 200
# ANOVA选择后的甲基化特征数量: 100
# 合并后的所选特征总数: 300
# 基因表达特征: 200
# 甲基化特征: 100
# Fold 1 - 训练模型...
# Fold 1 - 性能指标:
#   准确率: 0.9048
#   精确率: 0.9000
#   召回率: 0.9000
#   F1分数: 0.9000
#   AUC: 0.9682
#
# 执行第2折交叉验证...
# Fold 2 - 特征选择...
# 特征选择前:
# 总特征数量: 413846
# 基因表达特征数量: 40089
# 甲基化特征数量: 373787
# 方差过滤后的基因表达特征数量: 32676
# 方差过滤后的甲基化特征数量: 223934
# ANOVA选择后的基因表达特征数量: 200
# ANOVA选择后的甲基化特征数量: 100
# 合并后的所选特征总数: 300
# 基因表达特征: 200
# 甲基化特征: 100
# Fold 2 - 训练模型...
# Fold 2 - 性能指标:
#   准确率: 0.9048
#   精确率: 1.0000
#   召回率: 0.8182
#   F1分数: 0.9000
#   AUC: 0.9273
#
# 执行第3折交叉验证...
# Fold 3 - 特征选择...
# 特征选择前:
# 总特征数量: 413846
# 基因表达特征数量: 40089
# 甲基化特征数量: 373787
# 方差过滤后的基因表达特征数量: 32144
# 方差过滤后的甲基化特征数量: 227647
# ANOVA选择后的基因表达特征数量: 200
# ANOVA选择后的甲基化特征数量: 100
# 合并后的所选特征总数: 300
# 基因表达特征: 200
# 甲基化特征: 100
# Fold 3 - 训练模型...
# Fold 3 - 性能指标:
#   准确率: 0.9500
#   精确率: 1.0000
#   召回率: 0.9000
#   F1分数: 0.9474
#   AUC: 0.9400
#
# 执行第4折交叉验证...
# Fold 4 - 特征选择...
# 特征选择前:
# 总特征数量: 413846
# 基因表达特征数量: 40089
# 甲基化特征数量: 373787
# 方差过滤后的基因表达特征数量: 32600
# 方差过滤后的甲基化特征数量: 225842
# ANOVA选择后的基因表达特征数量: 200
# ANOVA选择后的甲基化特征数量: 100
# 合并后的所选特征总数: 300
# 基因表达特征: 200
# 甲基化特征: 100
# Fold 4 - 训练模型...
# Fold 4 - 性能指标:
#   准确率: 0.7500
#   精确率: 0.6923
#   召回率: 0.9000
#   F1分数: 0.7826
#   AUC: 0.9300
#
# 执行第5折交叉验证...
# Fold 5 - 特征选择...
# 特征选择前:
# 总特征数量: 413846
# 基因表达特征数量: 40089
# 甲基化特征数量: 373787
# 方差过滤后的基因表达特征数量: 32608
# 方差过滤后的甲基化特征数量: 227016
# ANOVA选择后的基因表达特征数量: 200
# ANOVA选择后的甲基化特征数量: 100
# 合并后的所选特征总数: 300
# 基因表达特征: 200
# 甲基化特征: 100
# Fold 5 - 训练模型...
# Fold 5 - 性能指标:
#   准确率: 0.9000
#   精确率: 0.8333
#   召回率: 1.0000
#   F1分数: 0.9091
#   AUC: 0.9800
#
# 交叉验证平均性能:
# 平均准确率: 0.8819
# 平均精确率: 0.8851
# 平均召回率: 0.9036
# 平均F1分数: 0.8878
# 平均AUC: 0.9491
