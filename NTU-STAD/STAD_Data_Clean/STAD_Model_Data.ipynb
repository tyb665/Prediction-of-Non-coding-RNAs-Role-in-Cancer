# %% [markdown]
# # PRAD_Model_TF_Expression_Features.csv

# %% [markdown]
# ## 处理表达

# %%
# Author: Weilin He
# Description: Remove the first column (Ensembl_ID) from the expression matrix.

import pandas as pd

base_path = "/Users/heweilin/Desktop/M-28-STAD/NTU_DATA_CLEANED/"

# Load the CSV file
prad_file = base_path + "STAD_TOIL_RSEM_TPM_Levels_After_DEG_DMA.csv"
prad_df = pd.read_csv(prad_file)

# Delete the first column (Ensembl_ID)
prad_df.drop(prad_df.columns[0], axis=1, inplace=True)

# Save the updated DataFrame back to the CSV file
prad_df.to_csv(prad_file, index=False)

# Print the first five rows to check the result
print(prad_df.head())
# Out:
#   HGNC_Symbol  TCGA_BR_A4J6  TCGA_IN_7808  TCGA_BR_A4QL  TCGA_BR_8372  \
# 0        TNMD       -9.9658       -4.6082       -3.3076       -0.0277
# 1         CFH        4.8228        4.0739        0.5069        3.3478
# 2       WNT16       -3.8160       -1.9379       -2.3147       -2.6349
# 3      KLHL13       -0.9686       -0.1504       -1.3183        3.2251
# 4      SLC7A2        0.6239        0.0990       -5.5735       -2.6349
#
#    TCGA_CG_4466  TCGA_BR_A4J9  TCGA_D7_A4Z0  TCGA_CG_4462  TCGA_IN_8663  ...  \
# 0       -9.9658       -9.9658       -5.0116       -9.9658       -9.9658  ...
# 1        3.5766        4.3227        5.2567        7.9228        2.8381  ...
# 2       -4.6082       -2.6349       -1.7322       -3.8160       -3.3076  ...
# 3       -2.1779        2.0673        0.0300        2.9071       -1.8836  ...
# 4        3.7625        1.3511        0.4552        2.8260       -0.7346  ...
#
#    TCGA_HF_7134  TCGA_VQ_A8PM  TCGA_BR_7959  TCGA_HU_A4GJ  TCGA_BR_4255  \
# 0       -9.9658       -4.6082       -4.6082       -3.8160     -2.826226
# 1        3.3492        4.6753        5.2126        4.6165      5.646756
# 2       -9.9658       -3.8160       -4.0350       -1.5522     -3.171369
# 3        0.9789        0.7748        1.1706       -0.3940      1.993136
# 4        0.0440        0.8568        3.7857        0.0440      2.136194
#
#    TCGA_BR_A4CR  TCGA_D7_A6EX  TCGA_HU_8602  TCGA_VQ_AA6F  TCGA_BR_8588
# 0       -4.6082       -9.9658       -9.9658       -9.9658       -3.1714
# 1        2.1247        2.3981        4.5886        4.0462        4.6960
# 2        1.3735       -3.1714        1.2085       -3.8160       -2.6349
# 3        0.2522       -1.1172       -2.9324        1.0503        0.4552
# 4        5.8590        2.0810       -1.3548       -1.0559        1.1833
#
# [5 rows x 415 columns]

# %%
# Author: Weilin He
# Description: Remove the first column (Ensembl_ID) from the expression matrix.

import pandas as pd

base_path = "/Users/heweilin/Desktop/M-28-STAD//NTU_DATA_CLEANED/"

# Load the CSV file
prad_file = base_path + "STAD_TOIL_RSEM_TPM_Levels.csv"
prad_df = pd.read_csv(prad_file)

# Delete the first column (Ensembl_ID)
prad_df.drop(prad_df.columns[0], axis=1, inplace=True)

# Save the updated DataFrame back to the CSV file
prad_df.to_csv(prad_file, index=False)

# Print the first five rows to check the result
print(prad_df.head())
# Out:
#   HGNC_Symbol  TCGA_BR_A4J6  TCGA_IN_7808  TCGA_BR_A4QL  TCGA_BR_8372  \
# 0      TSPAN6        4.1788        2.2663        3.7061        5.6642
# 1        TNMD       -9.9658       -4.6082       -3.3076       -0.0277
# 2        DPM1        5.6271        4.8405        4.7714        5.6085
# 3       SCYL3        1.8683        2.5900        0.8805        3.1212
# 4       FIRRM        0.5763        1.7360        1.5115        3.2915
#
#    TCGA_CG_4466  TCGA_BR_A4J9  TCGA_D7_A4Z0  TCGA_CG_4462  TCGA_IN_8663  ...  \
# 0        4.4364        1.9968        2.5828        3.7794        5.5160  ...
# 1       -9.9658       -9.9658       -5.0116       -9.9658       -9.9658  ...
# 2        6.5364        4.9737        4.9955        5.3374        6.4251  ...
# 3        2.8994        2.1862        1.9264        2.9090        2.6602  ...
# 4        3.3464        0.7493        1.2934        1.9188        3.6101  ...
#
#    TCGA_HF_7134  TCGA_VQ_A8PM  TCGA_BR_7959  TCGA_HU_A4GJ  TCGA_BR_4255  \
# 0        4.4516        3.9561        4.2518        2.5137      4.266459
# 1       -9.9658       -4.6082       -4.6082       -3.8160     -2.826226
# 2        5.6448        5.4575        5.4213        4.9737      5.569445
# 3        3.7496        2.5087        2.4934        2.5876      2.575573
# 4        3.9175        1.6374        2.3536        2.5061      2.493378
#
#    TCGA_BR_A4CR  TCGA_D7_A6EX  TCGA_HU_8602  TCGA_VQ_AA6F  TCGA_BR_8588
# 0        4.6821        1.8323        4.8223        3.2988        3.2959
# 1       -4.6082       -9.9658       -9.9658       -9.9658       -3.1714
# 2        6.1044        5.2950        5.6473        5.1526        5.1244
# 3        2.5388        2.5658        2.9562        2.5948        2.4090
# 4        3.3647        1.7273        3.7982        2.2206        2.9747
#
# [5 rows x 415 columns]

# %% [markdown]
# ## 处理tf

# %%
# Author: Weilin He
# Description: Remove the second row (GeneSym,GeneID,GeneSym,GeneID) from TF_Target.csv.

import pandas as pd

base_path = "/Users/heweilin/Desktop/M-28-STAD//NTU_DATA_CLEANED/"

# Load the TF_Target CSV file
tf_target_file = base_path + "TF_Target.csv"
tf_target_df = pd.read_csv(tf_target_file, dtype=str)

# Drop the first data row (which is currently index 0)
tf_target_df = tf_target_df.iloc[1:, :].reset_index(drop=True)

# Save the updated DataFrame back to the CSV file
tf_target_df.to_csv(tf_target_file, index=False)

# Print the first five rows to check the result
print(tf_target_df.head())
# Out:
#   HGNC_Symbol    Gene_ID TF_Symbol TF_ID
# 0        A1BG          1    ARID3A  1820
# 1    A1BG-AS1     503538    ARID3A  1820
# 2        A1CF      29974    ARID3A  1820
# 3         A2M          2    ARID3A  1820
# 4        AAA1  100329167    ARID3A  1820

# %% [markdown]
# ## 得到 PRAD_Model_TF_Expression_Features.csv

# %%
# Author: Weilin He
# Description: Generate Model_TF_Expression_Features.csv by replacing HGNC_Symbol with TF_Symbol.

import pandas as pd

base_path = "/Users/heweilin/Desktop/M-28-STAD//NTU_DATA_CLEANED/"

# Load the PRAD expression CSV file
prad_file = base_path + "STAD_TOIL_RSEM_TPM_Levels_After_DEG_DMA.csv"
prad_df = pd.read_csv(prad_file, dtype=str)

# Load the TF_Target CSV file
tf_target_file = base_path + "TF_Target.csv"
tf_target_df = pd.read_csv(tf_target_file, dtype=str)

# Merge dataframes on HGNC_Symbol to replace with TF_Symbol
merged_df = pd.merge(prad_df, tf_target_df[['HGNC_Symbol', 'TF_Symbol']], on='HGNC_Symbol', how='inner')

# Replace HGNC_Symbol with TF_Symbol and drop original HGNC_Symbol
merged_df.drop('HGNC_Symbol', axis=1, inplace=True)

# Reorder columns to place TF_Symbol first
cols = merged_df.columns.tolist()
cols.insert(0, cols.pop(cols.index('TF_Symbol')))
merged_df = merged_df[cols]

# Save the resulting DataFrame to a new CSV file
output_file = base_path + "STAD_Model_TF_Expression_Features.csv"
merged_df.to_csv(output_file, index=False)

# Print the first five rows to check the result
print(merged_df.head())
# Out:
#   TF_Symbol TCGA_BR_A4J6 TCGA_IN_7808 TCGA_BR_A4QL TCGA_BR_8372 TCGA_CG_4466  \
# 0      CTCF      -9.9658      -4.6082      -3.3076      -0.0277      -9.9658
# 1      EZH2      -9.9658      -4.6082      -3.3076      -0.0277      -9.9658
# 2     H2AFZ      -9.9658      -4.6082      -3.3076      -0.0277      -9.9658
# 3    POLR2A      -9.9658      -4.6082      -3.3076      -0.0277      -9.9658
# 4   SUPT20H      -9.9658      -4.6082      -3.3076      -0.0277      -9.9658
#
#   TCGA_BR_A4J9 TCGA_D7_A4Z0 TCGA_CG_4462 TCGA_IN_8663  ... TCGA_HF_7134  \
# 0      -9.9658      -5.0116      -9.9658      -9.9658  ...      -9.9658
# 1      -9.9658      -5.0116      -9.9658      -9.9658  ...      -9.9658
# 2      -9.9658      -5.0116      -9.9658      -9.9658  ...      -9.9658
# 3      -9.9658      -5.0116      -9.9658      -9.9658  ...      -9.9658
# 4      -9.9658      -5.0116      -9.9658      -9.9658  ...      -9.9658
#
#   TCGA_VQ_A8PM TCGA_BR_7959 TCGA_HU_A4GJ  TCGA_BR_4255 TCGA_BR_A4CR  \
# 0      -4.6082      -4.6082       -3.816  -2.826226098      -4.6082
# 1      -4.6082      -4.6082       -3.816  -2.826226098      -4.6082
# 2      -4.6082      -4.6082       -3.816  -2.826226098      -4.6082
# 3      -4.6082      -4.6082       -3.816  -2.826226098      -4.6082
# 4      -4.6082      -4.6082       -3.816  -2.826226098      -4.6082
#
#   TCGA_D7_A6EX TCGA_HU_8602 TCGA_VQ_AA6F TCGA_BR_8588
# 0      -9.9658      -9.9658      -9.9658      -3.1714
# 1      -9.9658      -9.9658      -9.9658      -3.1714
# 2      -9.9658      -9.9658      -9.9658      -3.1714
# 3      -9.9658      -9.9658      -9.9658      -3.1714
# 4      -9.9658      -9.9658      -9.9658      -3.1714
#
# [5 rows x 415 columns]

# %% [markdown]
# # PRAD_Model_Gene_Expression_Features.csv

# %%
# Author: Weilin He
# Description: Rename and save the PRAD expression data with an additional column.

import pandas as pd

base_path = "/Users/heweilin/Desktop/M-28-STAD/NTU_DATA_CLEANED/"

# Load the existing PRAD expression data
original_file = base_path + "STAD_TOIL_RSEM_TPM_Levels_After_DEG_DMA.csv"
prad_df = pd.read_csv(original_file)

# Save the updated DataFrame as a new CSV file
new_file = base_path + "STAD_Model_Gene_Expression_Features.csv"
prad_df.to_csv(new_file, index=False)

# Print the first five rows to check the result
print(prad_df.head())
# Out:
#   HGNC_Symbol  TCGA_BR_A4J6  TCGA_IN_7808  TCGA_BR_A4QL  TCGA_BR_8372  \
# 0        TNMD       -9.9658       -4.6082       -3.3076       -0.0277
# 1         CFH        4.8228        4.0739        0.5069        3.3478
# 2       WNT16       -3.8160       -1.9379       -2.3147       -2.6349
# 3      KLHL13       -0.9686       -0.1504       -1.3183        3.2251
# 4      SLC7A2        0.6239        0.0990       -5.5735       -2.6349
#
#    TCGA_CG_4466  TCGA_BR_A4J9  TCGA_D7_A4Z0  TCGA_CG_4462  TCGA_IN_8663  ...  \
# 0       -9.9658       -9.9658       -5.0116       -9.9658       -9.9658  ...
# 1        3.5766        4.3227        5.2567        7.9228        2.8381  ...
# 2       -4.6082       -2.6349       -1.7322       -3.8160       -3.3076  ...
# 3       -2.1779        2.0673        0.0300        2.9071       -1.8836  ...
# 4        3.7625        1.3511        0.4552        2.8260       -0.7346  ...
#
#    TCGA_HF_7134  TCGA_VQ_A8PM  TCGA_BR_7959  TCGA_HU_A4GJ  TCGA_BR_4255  \
# 0       -9.9658       -4.6082       -4.6082       -3.8160     -2.826226
# 1        3.3492        4.6753        5.2126        4.6165      5.646756
# 2       -9.9658       -3.8160       -4.0350       -1.5522     -3.171369
# 3        0.9789        0.7748        1.1706       -0.3940      1.993136
# 4        0.0440        0.8568        3.7857        0.0440      2.136194
#
#    TCGA_BR_A4CR  TCGA_D7_A6EX  TCGA_HU_8602  TCGA_VQ_AA6F  TCGA_BR_8588
# 0       -4.6082       -9.9658       -9.9658       -9.9658       -3.1714
# 1        2.1247        2.3981        4.5886        4.0462        4.6960
# 2        1.3735       -3.1714        1.2085       -3.8160       -2.6349
# 3        0.2522       -1.1172       -2.9324        1.0503        0.4552
# 4        5.8590        2.0810       -1.3548       -1.0559        1.1833
#
# [5 rows x 415 columns]

# %%
# Author: Weilin He
# Description: Rename and save the PRAD expression data with an additional column.

import pandas as pd

base_path = "/Users/heweilin/Desktop/M-28-STAD/NTU_DATA_CLEANED/"

# Load the existing PRAD expression data
original_file = base_path + "STAD_TOIL_RSEM_TPM_Levels.csv"
prad_df = pd.read_csv(original_file)

# Save the updated DataFrame as a new CSV file
new_file = base_path + "STAD_Model_Gene_Expression_Features_Test.csv"
prad_df.to_csv(new_file, index=False)

# Print the first five rows to check the result
print(prad_df.head())
# Out:
#   HGNC_Symbol  TCGA_BR_A4J6  TCGA_IN_7808  TCGA_BR_A4QL  TCGA_BR_8372  \
# 0      TSPAN6        4.1788        2.2663        3.7061        5.6642
# 1        TNMD       -9.9658       -4.6082       -3.3076       -0.0277
# 2        DPM1        5.6271        4.8405        4.7714        5.6085
# 3       SCYL3        1.8683        2.5900        0.8805        3.1212
# 4       FIRRM        0.5763        1.7360        1.5115        3.2915
#
#    TCGA_CG_4466  TCGA_BR_A4J9  TCGA_D7_A4Z0  TCGA_CG_4462  TCGA_IN_8663  ...  \
# 0        4.4364        1.9968        2.5828        3.7794        5.5160  ...
# 1       -9.9658       -9.9658       -5.0116       -9.9658       -9.9658  ...
# 2        6.5364        4.9737        4.9955        5.3374        6.4251  ...
# 3        2.8994        2.1862        1.9264        2.9090        2.6602  ...
# 4        3.3464        0.7493        1.2934        1.9188        3.6101  ...
#
#    TCGA_HF_7134  TCGA_VQ_A8PM  TCGA_BR_7959  TCGA_HU_A4GJ  TCGA_BR_4255  \
# 0        4.4516        3.9561        4.2518        2.5137      4.266459
# 1       -9.9658       -4.6082       -4.6082       -3.8160     -2.826226
# 2        5.6448        5.4575        5.4213        4.9737      5.569445
# 3        3.7496        2.5087        2.4934        2.5876      2.575573
# 4        3.9175        1.6374        2.3536        2.5061      2.493378
#
#    TCGA_BR_A4CR  TCGA_D7_A6EX  TCGA_HU_8602  TCGA_VQ_AA6F  TCGA_BR_8588
# 0        4.6821        1.8323        4.8223        3.2988        3.2959
# 1       -4.6082       -9.9658       -9.9658       -9.9658       -3.1714
# 2        6.1044        5.2950        5.6473        5.1526        5.1244
# 3        2.5388        2.5658        2.9562        2.5948        2.4090
# 4        3.3647        1.7273        3.7982        2.2206        2.9747
#
# [5 rows x 415 columns]

# %% [markdown]
# # PRAD_Model_Methylation_Features.csv

# %%
# Author: Weilin He
# Description: Rename and save the PRAD methylation data with an additional column.

import pandas as pd

base_path = "/Users/heweilin/Desktop/M-28-STAD/NTU_DATA_CLEANED/"

# Load the existing PRAD methylation data
original_file = base_path + "STAD_Methylation_Levels_After_DEG_DMA.csv"
methylation_df = pd.read_csv(original_file)

# Save the updated DataFrame as a new CSV file
new_file = base_path + "STAD_Model_Methylation_Features.csv"
methylation_df.to_csv(new_file, index=False)

# Print the first five rows to check the result
print(methylation_df.head())
# Out:
#      Probe_ID  TCGA-VQ-A94P-01  TCGA-D7-6521-01  TCGA-VQ-A8PE-01  \
# 0  cg17027195           0.1024           0.0960           0.0581
# 1  cg13479358           0.2348           0.4505           0.1308
# 2  cg22970357           0.2337           0.5650           0.4006
# 3  cg10382206           0.7165           0.3483           0.2659
# 4  cg13601977           0.7746           0.4790           0.7241
#
#    TCGA-D7-6519-01  TCGA-BR-6452-01  TCGA-BR-8485-01  TCGA-VQ-A8PO-01  \
# 0           0.9058           0.7273           0.0424           0.8035
# 1           0.7936           0.7045           0.1776           0.6484
# 2           0.7866           0.6309           0.3877           0.6462
# 3           0.6270           0.3176           0.2366           0.2313
# 4           0.9092           0.7452           0.5843           0.4849
#
#    TCGA-VQ-AA69-01  TCGA-BR-8683-01  ...  TCGA-D7-8573-01  TCGA-BR-A44T-01  \
# 0           0.9452           0.0356  ...           0.9110           0.0439
# 1           0.8968           0.7134  ...           0.7940           0.2847
# 2           0.8331           0.5595  ...           0.7171           0.3282
# 3           0.1125           0.5096  ...           0.1956           0.6136
# 4           0.1514           0.8881  ...           0.2827           0.7956
#
#    TCGA-RD-A8MV-01  TCGA-CD-8536-01  TCGA-BR-8360-01  TCGA-BR-8291-01  \
# 0           0.3053           0.7953           0.7900           0.0426
# 1           0.3324           0.3524           0.7208           0.1745
# 2           0.4606           0.5437           0.6775           0.4981
# 3           0.5210           0.4358           0.3429           0.2115
# 4           0.7592           0.5772           0.6073           0.7133
#
#    TCGA-FP-8210-01  TCGA-RD-A7BS-01  TCGA-BR-A44U-01  TCGA-CD-8529-01
# 0           0.0764           0.5055           0.6612           0.0521
# 1           0.2219           0.1021           0.7394           0.4965
# 2           0.2966           0.3977           0.6733           0.3913
# 3           0.6553           0.4084           0.6416           0.5390
# 4           0.7765           0.6681           0.4526           0.7341
#
# [5 rows x 399 columns]

# %%
# Author: Weilin He
# Description: Rename and save the PRAD methylation data with an additional column.

import pandas as pd

base_path = "/Users/heweilin/Desktop/M-28-STAD/NTU_DATA_CLEANED/"

# Load the existing PRAD methylation data
original_file = base_path + "STAD_Methylation_Levels.csv"
methylation_df = pd.read_csv(original_file)

# Save the updated DataFrame as a new CSV file
new_file = base_path + "STAD_Model_Methylation_Features_Test.csv"
methylation_df.to_csv(new_file, index=False)

# Print the first five rows to check the result
print(methylation_df.head())
# Out:
#      Probe_ID  TCGA-VQ-A94P-01  TCGA-D7-6521-01  TCGA-VQ-A8PE-01  \
# 0  cg13332474           0.0292           0.0316           0.0374
# 1  cg00651829           0.0195           0.0221           0.0239
# 2  cg17027195           0.1024           0.0960           0.0581
# 3  cg09868354           0.0716           0.0863           0.1128
# 4  cg03050183           0.1387           0.0937           0.0746
#
#    TCGA-D7-6519-01  TCGA-BR-6452-01  TCGA-BR-8485-01  TCGA-VQ-A8PO-01  \
# 0           0.0288           0.1329           0.1365           0.0321
# 1           0.0284           0.2258           0.0258           0.5080
# 2           0.9058           0.7273           0.0424           0.8035
# 3           0.0764           0.0689           0.0694           0.0609
# 4           0.0696           0.0818           0.1016           0.0924
#
#    TCGA-VQ-AA69-01  TCGA-BR-8683-01  ...  TCGA-D7-8573-01  TCGA-BR-A44T-01  \
# 0           0.8723           0.0276  ...           0.5999           0.0244
# 1           0.7349           0.0448  ...           0.6431           0.0257
# 2           0.9452           0.0356  ...           0.9110           0.0439
# 3           0.0814           0.0429  ...           0.0704           0.0515
# 4           0.1129           0.1243  ...           0.0584           0.1336
#
#    TCGA-RD-A8MV-01  TCGA-CD-8536-01  TCGA-BR-8360-01  TCGA-BR-8291-01  \
# 0           0.0382           0.0297           0.0290           0.0274
# 1           0.0218           0.3515           0.6029           0.0194
# 2           0.3053           0.7953           0.7900           0.0426
# 3           0.0636           0.0700           0.0662           0.0531
# 4           0.0592           0.0744           0.0520           0.0850
#
#    TCGA-FP-8210-01  TCGA-RD-A7BS-01  TCGA-BR-A44U-01  TCGA-CD-8529-01
# 0           0.0334           0.0310           0.0238           0.0324
# 1           0.0662           0.0184           0.0290           0.0170
# 2           0.0764           0.5055           0.6612           0.0521
# 3           0.0784           0.1344           0.0459           0.1320
# 4           0.1399           0.1310           0.1208           0.0915
#
# [5 rows x 399 columns]

# %% [markdown]
# ## 换成——

# %% [markdown]
# ## 把后缀为11的数据列全部删掉，然后删掉剩下数据中数据的-01后缀即可

# %%
import pandas as pd

# Step 1: Load the CSV file
file_path = "/Users/heweilin/Desktop/M-28-STAD/NTU_DATA_CLEANED/STAD_Model_Methylation_Features.csv"
df = pd.read_csv(file_path)

# Step 2: First replace '-' with '_' in all column names (this is crucial before further suffix processing)
df.columns = [col.replace("-", "_") for col in df.columns]

# Step 3: Remove columns that end with '_11'
df = df[[col for col in df.columns if not col.endswith("_11")]]

# Step 4: Remove '_01' suffix from remaining sample columns (not from 'Probe_ID')
new_columns = []
for col in df.columns:
    if col.endswith("_01"):
        new_columns.append(col[:-3])  # remove '_01'
    else:
        new_columns.append(col)
df.columns = new_columns

# Step 4: Remove '_06' suffix from remaining sample columns (not from 'Probe_ID')
new_columns = []
for col in df.columns:
    if col.endswith("_06"):
        new_columns.append(col[:-3])  # remove '_06'
    else:
        new_columns.append(col)
df.columns = new_columns

# Step 5: Display first 5 rows
print("Modified DataFrame (first 5 rows):")
print(df.head())

# Step 6: Overwrite the original CSV file
df.to_csv(file_path, index=False)
# Out:
# Modified DataFrame (first 5 rows):
#      Probe_ID  TCGA_VQ_A94P  TCGA_D7_6521  TCGA_VQ_A8PE  TCGA_D7_6519  \
# 0  cg17027195        0.1024        0.0960        0.0581        0.9058
# 1  cg13479358        0.2348        0.4505        0.1308        0.7936
# 2  cg22970357        0.2337        0.5650        0.4006        0.7866
# 3  cg10382206        0.7165        0.3483        0.2659        0.6270
# 4  cg13601977        0.7746        0.4790        0.7241        0.9092
#
#    TCGA_BR_6452  TCGA_BR_8485  TCGA_VQ_A8PO  TCGA_VQ_AA69  TCGA_BR_8683  ...  \
# 0        0.7273        0.0424        0.8035        0.9452        0.0356  ...
# 1        0.7045        0.1776        0.6484        0.8968        0.7134  ...
# 2        0.6309        0.3877        0.6462        0.8331        0.5595  ...
# 3        0.3176        0.2366        0.2313        0.1125        0.5096  ...
# 4        0.7452        0.5843        0.4849        0.1514        0.8881  ...
#
#    TCGA_D7_8573  TCGA_BR_A44T  TCGA_RD_A8MV  TCGA_CD_8536  TCGA_BR_8360  \
# 0        0.9110        0.0439        0.3053        0.7953        0.7900
# 1        0.7940        0.2847        0.3324        0.3524        0.7208
# 2        0.7171        0.3282        0.4606        0.5437        0.6775
# 3        0.1956        0.6136        0.5210        0.4358        0.3429
# 4        0.2827        0.7956        0.7592        0.5772        0.6073
#
#    TCGA_BR_8291  TCGA_FP_8210  TCGA_RD_A7BS  TCGA_BR_A44U  TCGA_CD_8529
# 0        0.0426        0.0764        0.5055        0.6612        0.0521
# 1        0.1745        0.2219        0.1021        0.7394        0.4965
# 2        0.4981        0.2966        0.3977        0.6733        0.3913
# 3        0.2115        0.6553        0.4084        0.6416        0.5390
# 4        0.7133        0.7765        0.6681        0.4526        0.7341
#
# [5 rows x 397 columns]

# %%
import pandas as pd

# Step 1: Load the CSV file
file_path = "/Users/heweilin/Desktop/M-28-STAD/NTU_DATA_CLEANED/STAD_Model_Methylation_Features_Test.csv"
df = pd.read_csv(file_path)

# Step 2: First replace '-' with '_' in all column names (this is crucial before further suffix processing)
df.columns = [col.replace("-", "_") for col in df.columns]

# Step 3: Remove columns that end with '_11'
df = df[[col for col in df.columns if not col.endswith("_11")]]

# Step 4: Remove '_01' suffix from remaining sample columns (not from 'Probe_ID')
new_columns = []
for col in df.columns:
    if col.endswith("_01"):
        new_columns.append(col[:-3])  # remove '_01'
    else:
        new_columns.append(col)
df.columns = new_columns

# Step 4: Remove '_06' suffix from remaining sample columns (not from 'Probe_ID')
new_columns = []
for col in df.columns:
    if col.endswith("_06"):
        new_columns.append(col[:-3])  # remove '_06'

# Step 5: Display first 5 rows
print("Modified DataFrame (first 5 rows):")
print(df.head())

# Step 6: Overwrite the original CSV file
df.to_csv(file_path, index=False)
# Out:
# Modified DataFrame (first 5 rows):
#      Probe_ID  TCGA_VQ_A94P  TCGA_D7_6521  TCGA_VQ_A8PE  TCGA_D7_6519  \
# 0  cg13332474        0.0292        0.0316        0.0374        0.0288
# 1  cg00651829        0.0195        0.0221        0.0239        0.0284
# 2  cg17027195        0.1024        0.0960        0.0581        0.9058
# 3  cg09868354        0.0716        0.0863        0.1128        0.0764
# 4  cg03050183        0.1387        0.0937        0.0746        0.0696
#
#    TCGA_BR_6452  TCGA_BR_8485  TCGA_VQ_A8PO  TCGA_VQ_AA69  TCGA_BR_8683  ...  \
# 0        0.1329        0.1365        0.0321        0.8723        0.0276  ...
# 1        0.2258        0.0258        0.5080        0.7349        0.0448  ...
# 2        0.7273        0.0424        0.8035        0.9452        0.0356  ...
# 3        0.0689        0.0694        0.0609        0.0814        0.0429  ...
# 4        0.0818        0.1016        0.0924        0.1129        0.1243  ...
#
#    TCGA_D7_8573  TCGA_BR_A44T  TCGA_RD_A8MV  TCGA_CD_8536  TCGA_BR_8360  \
# 0        0.5999        0.0244        0.0382        0.0297        0.0290
# 1        0.6431        0.0257        0.0218        0.3515        0.6029
# 2        0.9110        0.0439        0.3053        0.7953        0.7900
# 3        0.0704        0.0515        0.0636        0.0700        0.0662
# 4        0.0584        0.1336        0.0592        0.0744        0.0520
#
#    TCGA_BR_8291  TCGA_FP_8210  TCGA_RD_A7BS  TCGA_BR_A44U  TCGA_CD_8529
# 0        0.0274        0.0334        0.0310        0.0238        0.0324
# 1        0.0194        0.0662        0.0184        0.0290        0.0170
# 2        0.0426        0.0764        0.5055        0.6612        0.0521
# 3        0.0531        0.0784        0.1344        0.0459        0.1320
# 4        0.0850        0.1399        0.1310        0.1208        0.0915
#
# [5 rows x 397 columns]

# %% [markdown]
# # TF加上后缀

# %%
# Author: Weilin He
# Description: Add 'tf' prefix to TF_Symbol in PRAD_Model_TF_Expression_Features.csv and save as new CSV.

import pandas as pd

base_path = "/Users/heweilin/Desktop/M-28-STAD/NTU_DATA_CLEANED/"

# Load the PRAD_Model_TF_Expression_Features CSV file
input_file = base_path + "STAD_Model_TF_Expression_Features.csv"
df = pd.read_csv(input_file, dtype=str)

# Add 'tf' prefix to TF_Symbol column
df['TF_Symbol'] = 'tf' + df['TF_Symbol']

# Save the resulting DataFrame to a new CSV file
output_file = base_path + "STAD_Model_TF_Expression_Features_Withtf.csv"
df.to_csv(output_file, index=False)

# Print the first five rows to check the result
print(df.head())
# Out:
#    TF_Symbol TCGA_BR_A4J6 TCGA_IN_7808 TCGA_BR_A4QL TCGA_BR_8372 TCGA_CG_4466  \
# 0     tfCTCF      -9.9658      -4.6082      -3.3076      -0.0277      -9.9658
# 1     tfEZH2      -9.9658      -4.6082      -3.3076      -0.0277      -9.9658
# 2    tfH2AFZ      -9.9658      -4.6082      -3.3076      -0.0277      -9.9658
# 3   tfPOLR2A      -9.9658      -4.6082      -3.3076      -0.0277      -9.9658
# 4  tfSUPT20H      -9.9658      -4.6082      -3.3076      -0.0277      -9.9658
#
#   TCGA_BR_A4J9 TCGA_D7_A4Z0 TCGA_CG_4462 TCGA_IN_8663  ... TCGA_HF_7134  \
# 0      -9.9658      -5.0116      -9.9658      -9.9658  ...      -9.9658
# 1      -9.9658      -5.0116      -9.9658      -9.9658  ...      -9.9658
# 2      -9.9658      -5.0116      -9.9658      -9.9658  ...      -9.9658
# 3      -9.9658      -5.0116      -9.9658      -9.9658  ...      -9.9658
# 4      -9.9658      -5.0116      -9.9658      -9.9658  ...      -9.9658
#
#   TCGA_VQ_A8PM TCGA_BR_7959 TCGA_HU_A4GJ  TCGA_BR_4255 TCGA_BR_A4CR  \
# 0      -4.6082      -4.6082       -3.816  -2.826226098      -4.6082
# 1      -4.6082      -4.6082       -3.816  -2.826226098      -4.6082
# 2      -4.6082      -4.6082       -3.816  -2.826226098      -4.6082
# 3      -4.6082      -4.6082       -3.816  -2.826226098      -4.6082
# 4      -4.6082      -4.6082       -3.816  -2.826226098      -4.6082
#
#   TCGA_D7_A6EX TCGA_HU_8602 TCGA_VQ_AA6F TCGA_BR_8588
# 0      -9.9658      -9.9658      -9.9658      -3.1714
# 1      -9.9658      -9.9658      -9.9658      -3.1714
# 2      -9.9658      -9.9658      -9.9658      -3.1714
# 3      -9.9658      -9.9658      -9.9658      -3.1714
# 4      -9.9658      -9.9658      -9.9658      -3.1714
#
# [5 rows x 415 columns]

# %% [markdown]
# # 新的test的tf数据

# %%
import pandas as pd

# Load the two uploaded files
tf_target_path = r'/Users/heweilin/Desktop/M-28-STAD/NTU_DATA_CLEANED/TF_Target.csv'
expression_data_path = r'/Users/heweilin/Desktop/M-28-STAD/NTU_DATA_CLEANED/STAD_TOIL_RSEM_TPM_Levels.csv'

# Read CSV files
tf_target_df = pd.read_csv(tf_target_path)
expression_df = pd.read_csv(expression_data_path)

# Show the first few rows to understand the structure
tf_target_df.head(), expression_df.head()
# 合并 TF_Target 和 表达数据，通过 HGNC_Symbol 进行映射
merged_df = pd.merge(tf_target_df, expression_df, on="HGNC_Symbol", how="left")

# 只保留 TF_Symbol 和表达数据部分
expression_columns = expression_df.columns.difference(['Ensembl_ID', 'HGNC_Symbol'])
final_df = merged_df[['TF_Symbol'] + list(expression_columns)]

# 将结果保存为 CSV 文件
output_path = r'/Users/heweilin/Desktop/M-28-STAD/NTU_DATA_CLEANED/STAD_Model_TF_Expression_Features_Test.csv'
final_df.to_csv(output_path, index=False)
