# %% [markdown]
# # PRAD_Model_TF_Expression_Features.csv

# %% [markdown]
# ## 处理表达

# %%
# Author: Weilin He
# Description: Remove the first column (Ensembl_ID) from the expression matrix.

import pandas as pd

base_path = "/Users/heweilin/Desktop/M-28/NTU_DATA_CLEANED/"

# Load the CSV file
prad_file = base_path + "PRAD_TOIL_RSEM_TPM_Levels_After_DEG_DMA.csv"
prad_df = pd.read_csv(prad_file)

# Delete the first column (Ensembl_ID)
prad_df.drop(prad_df.columns[0], axis=1, inplace=True)

# Save the updated DataFrame back to the CSV file
prad_df.to_csv(prad_file, index=False)

# Print the first five rows to check the result
print(prad_df.head())
# Out:
#   HGNC_Symbol  TCGA_EJ_7125  TCGA_CH_5751  TCGA_KK_A7B3  TCGA_EJ_8468  \
# 0        TNMD       -3.8160       -5.0116       -3.8160       -3.4580
# 1         CFH        2.9469        3.8670        3.0234        4.5330
# 2        CFTR       -4.2934       -2.4659       -0.5125        1.8996
# 3       MYH16       -3.8160       -9.9658       -5.5735       -4.6082
# 4        AOC1       -1.7809       -1.9942        3.4156       -1.5951
#
#    TCGA_ZG_A8QW  TCGA_J4_A83K  TCGA_ZG_A9MC  TCGA_HC_7742  TCGA_M7_A722  ...  \
# 0       -9.9658        0.7058       -5.0116        0.8408       -3.0469  ...
# 1        3.3032        2.0325        4.1676        2.3843        0.7058  ...
# 2        1.6093       -0.1504        3.3321        0.0440       -4.2934  ...
# 3       -6.5064       -6.5064       -3.1714       -9.9658       -9.9658  ...
# 4        1.5415        2.4883        0.7233        1.1512       -3.6259  ...
#
#    TCGA_EJ_A7NH  TCGA_FC_A8O0  TCGA_HC_A6AP  TCGA_M7_A725  TCGA_HI_7171  \
# 0       -1.6394        0.5170        0.9268       -5.5735       -5.0116
# 1        2.9655        4.0278        3.6018        1.3109        2.3222
# 2       -0.5756       -0.8339        0.9493       -0.6643       -1.7322
# 3       -9.9658       -2.9324       -2.7274       -9.9658       -9.9658
# 4        4.9778        2.9432       -0.1187       -4.0350       -2.5479
#
#    TCGA_V1_A9ZR  TCGA_EJ_A6RC  TCGA_J4_8198  TCGA_CH_5768  TCGA_YL_A9WK
# 0       -2.8262       -0.3940       -2.4659       -5.0116       -0.0725
# 1        3.2002        4.0436        3.7215        2.4492        3.7730
# 2        1.9226        0.7493        0.5170        2.2633       -6.5064
# 3       -9.9658       -3.6259       -4.2934       -3.6259       -9.9658
# 4        0.2277       -1.2828        2.0111        0.7407       -3.6259
#
# [5 rows x 496 columns]

# %%
# Author: Weilin He
# Description: Remove the first column (Ensembl_ID) from the expression matrix.

import pandas as pd

base_path = "/Users/heweilin/Desktop/M-28/NTU_DATA_CLEANED/"

# Load the CSV file
prad_file = base_path + "PRAD_TOIL_RSEM_TPM_Levels.csv"
prad_df = pd.read_csv(prad_file)

# Delete the first column (Ensembl_ID)
prad_df.drop(prad_df.columns[0], axis=1, inplace=True)

# Save the updated DataFrame back to the CSV file
prad_df.to_csv(prad_file, index=False)

# Print the first five rows to check the result
print(prad_df.head())
# Out:
#   HGNC_Symbol  TCGA_EJ_7125  TCGA_CH_5751  TCGA_KK_A7B3  TCGA_EJ_8468  \
# 0      TSPAN6        5.7498        4.9860        4.5614        5.0348
# 1        TNMD       -3.8160       -5.0116       -3.8160       -3.4580
# 2        DPM1        4.7704        5.0233        4.8064        5.5583
# 3       SCYL3        2.2543        2.4753        2.1988        3.1924
# 4       FIRRM        1.0151        2.4805        0.8327        1.9264
#
#    TCGA_ZG_A8QW  TCGA_J4_A83K  TCGA_ZG_A9MC  TCGA_HC_7742  TCGA_M7_A722  ...  \
# 0        5.5056        5.4360        4.7693        5.5239        4.0713  ...
# 1       -9.9658        0.7058       -5.0116        0.8408       -3.0469  ...
# 2        5.0909        4.9668        5.1010        5.1281        3.6184  ...
# 3        2.1047        2.9966        2.6185        2.8877        0.3796  ...
# 4        1.5115        1.0293        1.4335        1.5465        0.4552  ...
#
#    TCGA_EJ_A7NH  TCGA_FC_A8O0  TCGA_HC_A6AP  TCGA_M7_A725  TCGA_HI_7171  \
# 0        5.0304        5.0401        5.0479        4.5243        5.2627
# 1       -1.6394        0.5170        0.9268       -5.5735       -5.0116
# 2        4.6713        5.0510        4.8329        5.2627        4.8340
# 3        2.4908        2.4883        1.5465        3.3134        3.1112
# 4        1.1382        1.2756        1.2455        1.8918        0.9642
#
#    TCGA_V1_A9ZR  TCGA_EJ_A6RC  TCGA_J4_8198  TCGA_CH_5768  TCGA_YL_A9WK
# 0        3.4778        5.0955        5.5192        5.8153        5.0540
# 1       -2.8262       -0.3940       -2.4659       -5.0116       -0.0725
# 2        4.7253        4.7746        4.7312        4.9393        4.9160
# 3        3.1377        2.5313        3.4933        3.4477        2.1080
# 4        1.0847        1.2696        1.4652        1.3225        0.6790
#
# [5 rows x 496 columns]

# %% [markdown]
# ## 处理tf

# %%
# Author: Weilin He
# Description: Remove the second row (GeneSym,GeneID,GeneSym,GeneID) from TF_Target.csv.

import pandas as pd

base_path = "/Users/heweilin/Desktop/M-28/NTU_DATA_CLEANED/"

# Load the TF_Target CSV file
tf_target_file = base_path + "TF_Target.csv"
tf_target_df = pd.read_csv(tf_target_file, dtype=str)

# Drop the first data row (which is currently index 0)
tf_target_df = tf_target_df.iloc[1:, :].reset_index(drop=True)

# Save the updated DataFrame back to the CSV file
tf_target_df.to_csv(tf_target_file, index=False)

# Print the first five rows to check the result
print(tf_target_df.head())
# Out:
#   HGNC_Symbol    Gene_ID TF_Symbol TF_ID
# 0    A1BG-AS1     503538    ARID3A  1820
# 1        A1CF      29974    ARID3A  1820
# 2         A2M          2    ARID3A  1820
# 3        AAA1  100329167    ARID3A  1820
# 4        AAAS       8086    ARID3A  1820

# %% [markdown]
# ## 得到 PRAD_Model_TF_Expression_Features.csv

# %%
# Author: Weilin He
# Description: Generate Model_TF_Expression_Features.csv by replacing HGNC_Symbol with TF_Symbol.

import pandas as pd

base_path = "/Users/heweilin/Desktop/M-28/NTU_DATA_CLEANED/"

# Load the PRAD expression CSV file
prad_file = base_path + "PRAD_TOIL_RSEM_TPM_Levels_After_DEG_DMA.csv"
prad_df = pd.read_csv(prad_file, dtype=str)

# Load the TF_Target CSV file
tf_target_file = base_path + "TF_Target.csv"
tf_target_df = pd.read_csv(tf_target_file, dtype=str)

# Merge dataframes on HGNC_Symbol to replace with TF_Symbol
merged_df = pd.merge(prad_df, tf_target_df[['HGNC_Symbol', 'TF_Symbol']], on='HGNC_Symbol', how='inner')

# Replace HGNC_Symbol with TF_Symbol and drop original HGNC_Symbol
merged_df.drop('HGNC_Symbol', axis=1, inplace=True)

# Reorder columns to place TF_Symbol first
cols = merged_df.columns.tolist()
cols.insert(0, cols.pop(cols.index('TF_Symbol')))
merged_df = merged_df[cols]

# Save the resulting DataFrame to a new CSV file
output_file = base_path + "PRAD_Model_TF_Expression_Features.csv"
merged_df.to_csv(output_file, index=False)

# Print the first five rows to check the result
print(merged_df.head())
# Out:
#   TF_Symbol TCGA_EJ_7125 TCGA_CH_5751 TCGA_KK_A7B3 TCGA_EJ_8468 TCGA_ZG_A8QW  \
# 0      CTCF       -3.816      -5.0116       -3.816       -3.458      -9.9658
# 1      EZH2       -3.816      -5.0116       -3.816       -3.458      -9.9658
# 2     H2AFZ       -3.816      -5.0116       -3.816       -3.458      -9.9658
# 3    POLR2A       -3.816      -5.0116       -3.816       -3.458      -9.9658
# 4   SUPT20H       -3.816      -5.0116       -3.816       -3.458      -9.9658
#
#   TCGA_J4_A83K TCGA_ZG_A9MC TCGA_HC_7742 TCGA_M7_A722  ... TCGA_EJ_A7NH  \
# 0       0.7058      -5.0116       0.8408      -3.0469  ...      -1.6394
# 1       0.7058      -5.0116       0.8408      -3.0469  ...      -1.6394
# 2       0.7058      -5.0116       0.8408      -3.0469  ...      -1.6394
# 3       0.7058      -5.0116       0.8408      -3.0469  ...      -1.6394
# 4       0.7058      -5.0116       0.8408      -3.0469  ...      -1.6394
#
#   TCGA_FC_A8O0 TCGA_HC_A6AP TCGA_M7_A725 TCGA_HI_7171 TCGA_V1_A9ZR  \
# 0        0.517       0.9268      -5.5735      -5.0116      -2.8262
# 1        0.517       0.9268      -5.5735      -5.0116      -2.8262
# 2        0.517       0.9268      -5.5735      -5.0116      -2.8262
# 3        0.517       0.9268      -5.5735      -5.0116      -2.8262
# 4        0.517       0.9268      -5.5735      -5.0116      -2.8262
#
#   TCGA_EJ_A6RC TCGA_J4_8198 TCGA_CH_5768 TCGA_YL_A9WK
# 0       -0.394      -2.4659      -5.0116      -0.0725
# 1       -0.394      -2.4659      -5.0116      -0.0725
# 2       -0.394      -2.4659      -5.0116      -0.0725
# 3       -0.394      -2.4659      -5.0116      -0.0725
# 4       -0.394      -2.4659      -5.0116      -0.0725
#
# [5 rows x 496 columns]

# %% [markdown]
# # PRAD_Model_Gene_Expression_Features.csv

# %%
# Author: Weilin He
# Description: Rename and save the PRAD expression data with an additional column.

import pandas as pd

base_path = "/Users/heweilin/Desktop/M-28/NTU_DATA_CLEANED/"

# Load the existing PRAD expression data
original_file = base_path + "PRAD_TOIL_RSEM_TPM_Levels_After_DEG_DMA.csv"
prad_df = pd.read_csv(original_file)

# Save the updated DataFrame as a new CSV file
new_file = base_path + "PRAD_Model_Gene_Expression_Features.csv"
prad_df.to_csv(new_file, index=False)

# Print the first five rows to check the result
print(prad_df.head())
# Out:
#   HGNC_Symbol  TCGA_EJ_7125  TCGA_CH_5751  TCGA_KK_A7B3  TCGA_EJ_8468  \
# 0        TNMD       -3.8160       -5.0116       -3.8160       -3.4580
# 1         CFH        2.9469        3.8670        3.0234        4.5330
# 2        CFTR       -4.2934       -2.4659       -0.5125        1.8996
# 3       MYH16       -3.8160       -9.9658       -5.5735       -4.6082
# 4        AOC1       -1.7809       -1.9942        3.4156       -1.5951
#
#    TCGA_ZG_A8QW  TCGA_J4_A83K  TCGA_ZG_A9MC  TCGA_HC_7742  TCGA_M7_A722  ...  \
# 0       -9.9658        0.7058       -5.0116        0.8408       -3.0469  ...
# 1        3.3032        2.0325        4.1676        2.3843        0.7058  ...
# 2        1.6093       -0.1504        3.3321        0.0440       -4.2934  ...
# 3       -6.5064       -6.5064       -3.1714       -9.9658       -9.9658  ...
# 4        1.5415        2.4883        0.7233        1.1512       -3.6259  ...
#
#    TCGA_EJ_A7NH  TCGA_FC_A8O0  TCGA_HC_A6AP  TCGA_M7_A725  TCGA_HI_7171  \
# 0       -1.6394        0.5170        0.9268       -5.5735       -5.0116
# 1        2.9655        4.0278        3.6018        1.3109        2.3222
# 2       -0.5756       -0.8339        0.9493       -0.6643       -1.7322
# 3       -9.9658       -2.9324       -2.7274       -9.9658       -9.9658
# 4        4.9778        2.9432       -0.1187       -4.0350       -2.5479
#
#    TCGA_V1_A9ZR  TCGA_EJ_A6RC  TCGA_J4_8198  TCGA_CH_5768  TCGA_YL_A9WK
# 0       -2.8262       -0.3940       -2.4659       -5.0116       -0.0725
# 1        3.2002        4.0436        3.7215        2.4492        3.7730
# 2        1.9226        0.7493        0.5170        2.2633       -6.5064
# 3       -9.9658       -3.6259       -4.2934       -3.6259       -9.9658
# 4        0.2277       -1.2828        2.0111        0.7407       -3.6259
#
# [5 rows x 496 columns]

# %%
# Author: Weilin He
# Description: Rename and save the PRAD expression data with an additional column.

import pandas as pd

base_path = "/Users/heweilin/Desktop/M-28/NTU_DATA_CLEANED/"

# Load the existing PRAD expression data
original_file = base_path + "PRAD_TOIL_RSEM_TPM_Levels.csv"
prad_df = pd.read_csv(original_file)

# Save the updated DataFrame as a new CSV file
new_file = base_path + "PRAD_Model_Gene_Expression_Features_Test.csv"
prad_df.to_csv(new_file, index=False)

# Print the first five rows to check the result
print(prad_df.head())
# Out:
#   HGNC_Symbol  TCGA_EJ_7125  TCGA_CH_5751  TCGA_KK_A7B3  TCGA_EJ_8468  \
# 0      TSPAN6        5.7498        4.9860        4.5614        5.0348
# 1        TNMD       -3.8160       -5.0116       -3.8160       -3.4580
# 2        DPM1        4.7704        5.0233        4.8064        5.5583
# 3       SCYL3        2.2543        2.4753        2.1988        3.1924
# 4       FIRRM        1.0151        2.4805        0.8327        1.9264
#
#    TCGA_ZG_A8QW  TCGA_J4_A83K  TCGA_ZG_A9MC  TCGA_HC_7742  TCGA_M7_A722  ...  \
# 0        5.5056        5.4360        4.7693        5.5239        4.0713  ...
# 1       -9.9658        0.7058       -5.0116        0.8408       -3.0469  ...
# 2        5.0909        4.9668        5.1010        5.1281        3.6184  ...
# 3        2.1047        2.9966        2.6185        2.8877        0.3796  ...
# 4        1.5115        1.0293        1.4335        1.5465        0.4552  ...
#
#    TCGA_EJ_A7NH  TCGA_FC_A8O0  TCGA_HC_A6AP  TCGA_M7_A725  TCGA_HI_7171  \
# 0        5.0304        5.0401        5.0479        4.5243        5.2627
# 1       -1.6394        0.5170        0.9268       -5.5735       -5.0116
# 2        4.6713        5.0510        4.8329        5.2627        4.8340
# 3        2.4908        2.4883        1.5465        3.3134        3.1112
# 4        1.1382        1.2756        1.2455        1.8918        0.9642
#
#    TCGA_V1_A9ZR  TCGA_EJ_A6RC  TCGA_J4_8198  TCGA_CH_5768  TCGA_YL_A9WK
# 0        3.4778        5.0955        5.5192        5.8153        5.0540
# 1       -2.8262       -0.3940       -2.4659       -5.0116       -0.0725
# 2        4.7253        4.7746        4.7312        4.9393        4.9160
# 3        3.1377        2.5313        3.4933        3.4477        2.1080
# 4        1.0847        1.2696        1.4652        1.3225        0.6790
#
# [5 rows x 496 columns]

# %% [markdown]
# # PRAD_Model_Methylation_Features.csv

# %%
# Author: Weilin He
# Description: Rename and save the PRAD methylation data with an additional column.

import pandas as pd

base_path = "/Users/heweilin/Desktop/M-28/NTU_DATA_CLEANED/"

# Load the existing PRAD methylation data
original_file = base_path + "PRAD_Methylation_Levels_After_DEG_DMA.csv"
methylation_df = pd.read_csv(original_file)

# Save the updated DataFrame as a new CSV file
new_file = base_path + "PRAD_Model_Methylation_Features.csv"
methylation_df.to_csv(new_file, index=False)

# Print the first five rows to check the result
print(methylation_df.head())
# Out:
#      Probe_ID  TCGA-G9-6343-01  TCGA-KK-A8IA-01  TCGA-KK-A6E4-01  \
# 0  cg14142965           0.6230           0.5463           0.7656
# 1  cg16288089           0.2442           0.8335           0.8178
# 2  cg18103730           0.6849           0.6807           0.7907
# 3  cg09411231           0.3932           0.2346           0.2938
# 4  cg09784335           0.4664           0.8675           0.7876
#
#    TCGA-EJ-AB20-01  TCGA-H9-7775-01  TCGA-XJ-A9DX-01  TCGA-KK-A6E6-01  \
# 0           0.1095           0.6708           0.6196           0.5291
# 1           0.5308           0.7900           0.6956           0.7500
# 2           0.3309           0.7016           0.5093           0.4964
# 3           0.8413           0.3044           0.3466           0.4626
# 4           0.0666           0.7679           0.7682           0.6274
#
#    TCGA-G9-6339-01  TCGA-EJ-5509-01  ...  TCGA-EJ-7312-01  TCGA-V1-A8MM-01  \
# 0           0.3212           0.3330  ...           0.7606           0.5774
# 1           0.5981           0.6895  ...           0.7838           0.7577
# 2           0.4165           0.1653  ...           0.7552           0.6615
# 3           0.5817           0.5656  ...           0.3571           0.2045
# 4           0.5469           0.6216  ...           0.7513           0.8462
#
#    TCGA-EJ-A65F-01  TCGA-G9-6498-01  TCGA-EJ-5505-01  TCGA-CH-5761-11  \
# 0           0.6740           0.5785           0.3248           0.0427
# 1           0.7769           0.7555           0.5630           0.0737
# 2           0.6904           0.6245           0.3396           0.0630
# 3           0.3597           0.4023           0.5831           0.8969
# 4           0.7395           0.6344           0.5080           0.1245
#
#    TCGA-HC-8261-01  TCGA-XQ-A8TB-01  TCGA-G9-6329-01  TCGA-EJ-5496-01
# 0          0.40945           0.4363           0.2051           0.2523
# 1          0.53885           0.6977           0.4970           0.6001
# 2          0.39875           0.5504           0.2203           0.2132
# 3          0.53045           0.6274           0.7280           0.5444
# 4          0.50140           0.7354           0.4057           0.5573
#
# [5 rows x 550 columns]

# %%
# Author: Weilin He
# Description: Rename and save the PRAD methylation data with an additional column.

import pandas as pd

base_path = "/Users/heweilin/Desktop/M-28/NTU_DATA_CLEANED/"

# Load the existing PRAD methylation data
original_file = base_path + "PRAD_Methylation_Levels.csv"
methylation_df = pd.read_csv(original_file)

# Save the updated DataFrame as a new CSV file
new_file = base_path + "PRAD_Model_Methylation_Features_Test.csv"
methylation_df.to_csv(new_file, index=False)

# Print the first five rows to check the result
print(methylation_df.head())
# Out:
#      Probe_ID  TCGA-G9-6343-01  TCGA-KK-A8IA-01  TCGA-KK-A6E4-01  \
# 0  cg13332474           0.4721           0.4169           0.8249
# 1  cg00651829           0.0397           0.5916           0.6979
# 2  cg17027195           0.0422           0.0409           0.0459
# 3  cg09868354           0.0444           0.0922           0.0444
# 4  cg03050183           0.0784           0.0988           0.1561
#
#    TCGA-EJ-AB20-01  TCGA-H9-7775-01  TCGA-XJ-A9DX-01  TCGA-KK-A6E6-01  \
# 0           0.4844           0.5133           0.4510           0.5251
# 1           0.0172           0.5382           0.0169           0.5381
# 2           0.0391           0.0311           0.0451           0.0580
# 3           0.0867           0.0571           0.0492           0.0456
# 4           0.0941           0.0815           0.0693           0.3764
#
#    TCGA-G9-6339-01  TCGA-EJ-5509-01  ...  TCGA-EJ-7312-01  TCGA-V1-A8MM-01  \
# 0           0.3138           0.6834  ...           0.5436           0.3365
# 1           0.3938           0.3624  ...           0.4320           0.6108
# 2           0.0585           0.0452  ...           0.0603           0.0404
# 3           0.0573           0.0653  ...           0.1773           0.0771
# 4           0.1475           0.0786  ...           0.0753           0.0987
#
#    TCGA-EJ-A65F-01  TCGA-G9-6498-01  TCGA-EJ-5505-01  TCGA-CH-5761-11  \
# 0           0.4008           0.0750           0.1677           0.3603
# 1           0.6632           0.2804           0.4091           0.0328
# 2           0.0456           0.0478           0.0368           0.0343
# 3           0.0468           0.0468           0.0514           0.0515
# 4           0.0867           0.0616           0.0829           0.1152
#
#    TCGA-HC-8261-01  TCGA-XQ-A8TB-01  TCGA-G9-6329-01  TCGA-EJ-5496-01
# 0          0.59720           0.6409           0.5012           0.4549
# 1          0.34665           0.6153           0.1273           0.4383
# 2          0.06340           0.0507           0.0441           0.0378
# 3          0.06005           0.1549           0.0359           0.0487
# 4          0.09675           0.3103           0.2192           0.0995
#
# [5 rows x 550 columns]

# %% [markdown]
# ## 换成——

# %% [markdown]
# ## 把后缀为11的数据列全部删掉，然后删掉剩下数据中数据的-01后缀即可

# %%
import pandas as pd

# Step 1: Load the CSV file
file_path = "/Users/heweilin/Desktop/M-28/NTU_DATA_CLEANED/PRAD_Model_Methylation_Features.csv"
df = pd.read_csv(file_path)

# Step 2: First replace '-' with '_' in all column names (this is crucial before further suffix processing)
df.columns = [col.replace("-", "_") for col in df.columns]

# Step 3: Remove columns that end with '_11'
df = df[[col for col in df.columns if not col.endswith("_11")]]

# Step 4: Remove '_01' suffix from remaining sample columns (not from 'Probe_ID')
new_columns = []
for col in df.columns:
    if col.endswith("_01"):
        new_columns.append(col[:-3])  # remove '_01'
    else:
        new_columns.append(col)
df.columns = new_columns

# Step 5: Display first 5 rows
print("Modified DataFrame (first 5 rows):")
print(df.head())

# Step 6: Overwrite the original CSV file
df.to_csv(file_path, index=False)
# Out:
# Modified DataFrame (first 5 rows):
#      Probe_ID  TCGA_G9_6343  TCGA_KK_A8IA  TCGA_KK_A6E4  TCGA_EJ_AB20  \
# 0  cg14142965        0.6230        0.5463        0.7656        0.1095
# 1  cg16288089        0.2442        0.8335        0.8178        0.5308
# 2  cg18103730        0.6849        0.6807        0.7907        0.3309
# 3  cg09411231        0.3932        0.2346        0.2938        0.8413
# 4  cg09784335        0.4664        0.8675        0.7876        0.0666
#
#    TCGA_H9_7775  TCGA_XJ_A9DX  TCGA_KK_A6E6  TCGA_G9_6339  TCGA_EJ_5509  ...  \
# 0        0.6708        0.6196        0.5291        0.3212        0.3330  ...
# 1        0.7900        0.6956        0.7500        0.5981        0.6895  ...
# 2        0.7016        0.5093        0.4964        0.4165        0.1653  ...
# 3        0.3044        0.3466        0.4626        0.5817        0.5656  ...
# 4        0.7679        0.7682        0.6274        0.5469        0.6216  ...
#
#    TCGA_VN_A88L  TCGA_EJ_7312  TCGA_V1_A8MM  TCGA_EJ_A65F  TCGA_G9_6498  \
# 0        0.3728        0.7606        0.5774        0.6740        0.5785
# 1        0.5509        0.7838        0.7577        0.7769        0.7555
# 2        0.3320        0.7552        0.6615        0.6904        0.6245
# 3        0.5770        0.3571        0.2045        0.3597        0.4023
# 4        0.6528        0.7513        0.8462        0.7395        0.6344
#
#    TCGA_EJ_5505  TCGA_HC_8261  TCGA_XQ_A8TB  TCGA_G9_6329  TCGA_EJ_5496
# 0        0.3248       0.40945        0.4363        0.2051        0.2523
# 1        0.5630       0.53885        0.6977        0.4970        0.6001
# 2        0.3396       0.39875        0.5504        0.2203        0.2132
# 3        0.5831       0.53045        0.6274        0.7280        0.5444
# 4        0.5080       0.50140        0.7354        0.4057        0.5573
#
# [5 rows x 500 columns]

# %%
import pandas as pd

# Step 1: Load the CSV file
file_path = "/Users/heweilin/Desktop/M-28/NTU_DATA_CLEANED/PRAD_Model_Methylation_Features_Test.csv"
df = pd.read_csv(file_path)

# Step 2: First replace '-' with '_' in all column names (this is crucial before further suffix processing)
df.columns = [col.replace("-", "_") for col in df.columns]

# Step 3: Remove columns that end with '_11'
df = df[[col for col in df.columns if not col.endswith("_11")]]

# Step 4: Remove '_01' suffix from remaining sample columns (not from 'Probe_ID')
new_columns = []
for col in df.columns:
    if col.endswith("_01"):
        new_columns.append(col[:-3])  # remove '_01'
    else:
        new_columns.append(col)
df.columns = new_columns

# Step 5: Display first 5 rows
print("Modified DataFrame (first 5 rows):")
print(df.head())

# Step 6: Overwrite the original CSV file
df.to_csv(file_path, index=False)
# Out:
# Modified DataFrame (first 5 rows):
#      Probe_ID  TCGA_G9_6343  TCGA_KK_A8IA  TCGA_KK_A6E4  TCGA_EJ_AB20  \
# 0  cg13332474        0.4721        0.4169        0.8249        0.4844
# 1  cg00651829        0.0397        0.5916        0.6979        0.0172
# 2  cg17027195        0.0422        0.0409        0.0459        0.0391
# 3  cg09868354        0.0444        0.0922        0.0444        0.0867
# 4  cg03050183        0.0784        0.0988        0.1561        0.0941
#
#    TCGA_H9_7775  TCGA_XJ_A9DX  TCGA_KK_A6E6  TCGA_G9_6339  TCGA_EJ_5509  ...  \
# 0        0.5133        0.4510        0.5251        0.3138        0.6834  ...
# 1        0.5382        0.0169        0.5381        0.3938        0.3624  ...
# 2        0.0311        0.0451        0.0580        0.0585        0.0452  ...
# 3        0.0571        0.0492        0.0456        0.0573        0.0653  ...
# 4        0.0815        0.0693        0.3764        0.1475        0.0786  ...
#
#    TCGA_VN_A88L  TCGA_EJ_7312  TCGA_V1_A8MM  TCGA_EJ_A65F  TCGA_G9_6498  \
# 0        0.3575        0.5436        0.3365        0.4008        0.0750
# 1        0.5124        0.4320        0.6108        0.6632        0.2804
# 2        0.0523        0.0603        0.0404        0.0456        0.0478
# 3        0.0988        0.1773        0.0771        0.0468        0.0468
# 4        0.4702        0.0753        0.0987        0.0867        0.0616
#
#    TCGA_EJ_5505  TCGA_HC_8261  TCGA_XQ_A8TB  TCGA_G9_6329  TCGA_EJ_5496
# 0        0.1677       0.59720        0.6409        0.5012        0.4549
# 1        0.4091       0.34665        0.6153        0.1273        0.4383
# 2        0.0368       0.06340        0.0507        0.0441        0.0378
# 3        0.0514       0.06005        0.1549        0.0359        0.0487
# 4        0.0829       0.09675        0.3103        0.2192        0.0995
#
# [5 rows x 500 columns]

# %% [markdown]
# # TF加上后缀

# %%
# Author: Weilin He
# Description: Add 'tf' prefix to TF_Symbol in PRAD_Model_TF_Expression_Features.csv and save as new CSV.

import pandas as pd

base_path = "/Users/heweilin/Desktop/M-28/NTU_DATA_CLEANED/"

# Load the PRAD_Model_TF_Expression_Features CSV file
input_file = base_path + "PRAD_Model_TF_Expression_Features.csv"
df = pd.read_csv(input_file, dtype=str)

# Add 'tf' prefix to TF_Symbol column
df['TF_Symbol'] = 'tf' + df['TF_Symbol']

# Save the resulting DataFrame to a new CSV file
output_file = base_path + "PRAD_Model_TF_Expression_Features_Withtf.csv"
df.to_csv(output_file, index=False)

# Print the first five rows to check the result
print(df.head())
# Out:
#    TF_Symbol TCGA_EJ_7125 TCGA_CH_5751 TCGA_KK_A7B3 TCGA_EJ_8468 TCGA_ZG_A8QW  \
# 0     tfCTCF       -3.816      -5.0116       -3.816       -3.458      -9.9658
# 1     tfEZH2       -3.816      -5.0116       -3.816       -3.458      -9.9658
# 2    tfH2AFZ       -3.816      -5.0116       -3.816       -3.458      -9.9658
# 3   tfPOLR2A       -3.816      -5.0116       -3.816       -3.458      -9.9658
# 4  tfSUPT20H       -3.816      -5.0116       -3.816       -3.458      -9.9658
#
#   TCGA_J4_A83K TCGA_ZG_A9MC TCGA_HC_7742 TCGA_M7_A722  ... TCGA_EJ_A7NH  \
# 0       0.7058      -5.0116       0.8408      -3.0469  ...      -1.6394
# 1       0.7058      -5.0116       0.8408      -3.0469  ...      -1.6394
# 2       0.7058      -5.0116       0.8408      -3.0469  ...      -1.6394
# 3       0.7058      -5.0116       0.8408      -3.0469  ...      -1.6394
# 4       0.7058      -5.0116       0.8408      -3.0469  ...      -1.6394
#
#   TCGA_FC_A8O0 TCGA_HC_A6AP TCGA_M7_A725 TCGA_HI_7171 TCGA_V1_A9ZR  \
# 0        0.517       0.9268      -5.5735      -5.0116      -2.8262
# 1        0.517       0.9268      -5.5735      -5.0116      -2.8262
# 2        0.517       0.9268      -5.5735      -5.0116      -2.8262
# 3        0.517       0.9268      -5.5735      -5.0116      -2.8262
# 4        0.517       0.9268      -5.5735      -5.0116      -2.8262
#
#   TCGA_EJ_A6RC TCGA_J4_8198 TCGA_CH_5768 TCGA_YL_A9WK
# 0       -0.394      -2.4659      -5.0116      -0.0725
# 1       -0.394      -2.4659      -5.0116      -0.0725
# 2       -0.394      -2.4659      -5.0116      -0.0725
# 3       -0.394      -2.4659      -5.0116      -0.0725
# 4       -0.394      -2.4659      -5.0116      -0.0725
#
# [5 rows x 496 columns]

# %% [markdown]
# # 新的test的tf数据

# %%
import pandas as pd

# Load the two uploaded files
tf_target_path = r'/Users/heweilin/Desktop/M-28/NTU_DATA_CLEANED/TF_Target.csv'
expression_data_path = r'/Users/heweilin/Desktop/M-28/NTU_DATA_CLEANED/PRAD_TOIL_RSEM_TPM_Levels.csv'

# Read CSV files
tf_target_df = pd.read_csv(tf_target_path)
expression_df = pd.read_csv(expression_data_path)

# Show the first few rows to understand the structure
tf_target_df.head(), expression_df.head()
# 合并 TF_Target 和 表达数据，通过 HGNC_Symbol 进行映射
merged_df = pd.merge(tf_target_df, expression_df, on="HGNC_Symbol", how="left")

# 只保留 TF_Symbol 和表达数据部分
expression_columns = expression_df.columns.difference(['Ensembl_ID', 'HGNC_Symbol'])
final_df = merged_df[['TF_Symbol'] + list(expression_columns)]

# 将结果保存为 CSV 文件
output_path = r'/Users/heweilin/Desktop/M-28/NTU_DATA_CLEANED/PRAD_Model_TF_Expression_Features_Test.csv'
final_df.to_csv(output_path, index=False)
